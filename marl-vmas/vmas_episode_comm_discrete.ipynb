# %%
import time
import torch
from vmas import make_env
from vmas.simulator.core import Agent
from vmas.simulator.scenario import BaseScenario
from typing import Union
from moviepy.editor import ImageSequenceClip
from IPython.display import HTML, display as ipython_display
import numpy as np

class VMASEnvRunner:
    def __init__(
        self,
        render: bool,
        num_envs: int,
        num_episodes: int,
        max_steps_per_episode: int,
        device: str,
        scenario: Union[str, BaseScenario],
        continuous_actions: bool,
        random_action: bool,
        obs_discrete: bool = False,
        **kwargs
    ):
        self.render = render
        self.num_envs = num_envs
        self.num_episodes = num_episodes
        self.max_steps_per_episode = max_steps_per_episode
        self.device = device
        self.scenario = scenario
        self.continuous_actions = continuous_actions
        self.random_action = random_action
        self.obs_discrete = obs_discrete
        self.kwargs = kwargs
        self.frame_list = []  # Initialize frame list

    def discretize(self, data, bins):
   
        # Ensure the bins are a numpy array
        bins = np.array(bins)
        
        # Check if the input data is a single value
        if np.isscalar(data):
            bin_indices = np.digitize([data], bins)[0]
            bin_values = bins[bin_indices - 1] if bin_indices > 0 else bins[0]
            return bin_indices, bin_values
        else:
            # Use numpy.digitize to get the bin indices for array-like data
            bin_indices = np.digitize(data, bins)
            # Map indices to bin values
            bin_values = [bins[index - 1] if index > 0 else bins[0] for index in bin_indices]
            return bin_indices, bin_values


    # Function to discretize a tensor slice
    def discretize_tensor_slice(self, tensor_slice, bins):
        indices = []
        values = []
        for row in tensor_slice:
            row_indices = []
            row_values = []
            for item in row:
                bin_idx, bin_val = self.discretize(item.item(), bins)
                row_indices.append(bin_idx)
                row_values.append(bin_val)
            indices.append(row_indices)
            values.append(row_values)
        return torch.tensor(indices, device=tensor_slice.device), torch.tensor(values, device=tensor_slice.device)



    def _get_deterministic_obs(self, observation):

        # Define bin edges
        pos_bins = np.linspace(-1, 1, num=21)  # [0, 0.05, 0.1, 0.15, .. , 1]
        vel_bins = np.linspace(-1, 1, num=21)  # [0, 0.05, 0.1, 0.15, .. , 1]
        lidar_bins = np.linspace(0, 1, num=21)  # [0, 0.05, 0.1, 0.15, .. , 1]

        # Split observation into components
        pos = observation[:, :2]
        vel = observation[:, 2:4]
        goal_pose = observation[:, 4:6]
        sensor_data = observation[:, 6:18]  # Assuming lidar measurements are 12-dimensional
        comms_data = observation[:, 18:]    # Assuming communication data is already discrete


        # Discretize each part of the observation
        discrete_pos_indices, discrete_pos_values = self.discretize_tensor_slice(pos, pos_bins)
        discrete_vel_indices, discrete_vel_values = self.discretize_tensor_slice(vel, vel_bins)
        discrete_goal_pose_indices, discrete_goal_pose_values = self.discretize_tensor_slice(goal_pose, pos_bins)
        discrete_sensor_data_indices, discrete_sensor_data_values = self.discretize_tensor_slice(sensor_data, lidar_bins)

        # result = {
        #     "discrete_pos_indices": discrete_pos_indices,
        #     "discrete_pos_values": discrete_pos_values,
        #     "discrete_vel_indices": discrete_vel_indices,
        #     "discrete_vel_values": discrete_vel_values,
        #     "discrete_goal_pose_indices": discrete_goal_pose_indices,
        #     "discrete_goal_pose_values": discrete_goal_pose_values,
        #     "discrete_sensor_data_indices": discrete_sensor_data_indices,
        #     "discrete_sensor_data_values": discrete_sensor_data_values,
        #     "comms_data": comms_data
        # }

        concatenated_tensor_indices = torch.cat(
            [discrete_pos_indices, discrete_vel_indices, discrete_goal_pose_indices, discrete_sensor_data_indices],
            dim=1
        )
        concatenated_tensor_values = torch.cat(
            [discrete_pos_values, discrete_vel_values, discrete_goal_pose_values, discrete_sensor_data_values],
            dim=1
        )
        
        return concatenated_tensor_values

    def _get_deterministic_action(self, agent: Agent, env, agent_id, observation_id):
        if self.continuous_actions:
            if agent.silent:
                action = torch.tensor([[-1, 0.5]], device=env.device) # range action is [-1, 1] of a paired value and agent silent = true
            else:
                if agent_id == 0:
                    action = torch.tensor([[-1, 0.5, 0, 0]], device=env.device) # range action is [-1, 1] of a paired value and agent silent = false and c=1
                else:
                    action = torch.tensor([[-1, 0.5, 1, 1]], device=env.device) # range action is [-1, 1] of a paired value and agent silent = false and c=1
        else:
            action = torch.tensor([[10]], device=env.device) 
            # range discrete action = [0/1:stay, 2/3:down, 4/5:up, 6/7:left, 8/9:bottom-left, 10/11:top-left, 12/13:right, 14/15:bottom-right, 16/17:top-right] of a single value
        
        return action.clone()


    def generate_gif(self, scenario_name):
        fps = 30
        clip = ImageSequenceClip(self.frame_list, fps=fps)
        clip.write_gif(f'{scenario_name}.gif', fps=fps)

        # Return the HTML tag to display the GIF
        return HTML(f'<img src="{scenario_name}.gif">')

    def run_vmas_env(self):
        scenario_name = self.scenario if isinstance(self.scenario, str) else self.scenario.__class__.__name__

        env = make_env(
            scenario=self.scenario,
            num_envs=self.num_envs,
            device=self.device,
            continuous_actions=self.continuous_actions,
            seed=0,
            **self.kwargs
        )

        init_time = time.time()
        total_steps = 0
        
        for e in range(self.num_episodes):  # Loop over episodes
            print(f"Episode {e}")
            obs = env.reset()  # Reset environment at the start of each episode
            done = [False] * self.num_envs
            step = 0
            while not all(done) and step < self.max_steps_per_episode:  # Loop over steps within an episode
                step += 1
                total_steps += 1
                print(f"Step {step} of Episode {e}")

                actions = []
                for i, agent in enumerate(env.agents):

                    if self.obs_discrete:
                        print(f"obs agent {i}: {obs[i]}")
                        discrete_obs = self._get_deterministic_obs(obs[i])
                        obs[i] = discrete_obs
                        print(f"discrete obs of agent {i}: {obs[i]}")

                    if self.random_action:
                        action = env.get_random_action(agent)
                    else:
                        action = self._get_deterministic_action(agent, env, i, obs[i])
                    
                    print(f"action agent {i}: {action}")
                    actions.append(action)

                obs, rews, dones, info = env.step(actions)
                done = [done or d for done, d in zip(done, dones)]
                print(f"obs agent after step {step}: {obs}")
                print(f"rews agent: {rews}")

                if self.render:
                    frame = env.render(
                        mode="rgb_array",
                        agent_index_focus=None,
                    )
                    self.frame_list.append(frame)  # Append frame to the list

        total_time = time.time() - init_time
        print(
            f"It took: {total_time}s for {total_steps} steps across {self.num_episodes} episodes of {self.num_envs} parallel environments on device {self.device} "
            f"for {scenario_name} scenario."
        )

if __name__ == "__main__":
    scenario_name = "navigation_comm"

    env_runner = VMASEnvRunner(
        render=True,
        num_envs=1,
        num_episodes=1,
        max_steps_per_episode=100,
        device="cuda",
        scenario=scenario_name,
        continuous_actions=False,
        random_action=False,
        obs_discrete=True,  
        n_agents=3,
    )
    # Run the VMAS environment
    env_runner.run_vmas_env()

    # Generate and display the GIF
    ipython_display(env_runner.generate_gif(scenario_name))
# Out:
# Episode 0
# Step 1 of Episode 0
# obs agent 0: tensor([[ 0.2913, -0.2901,  0.0000,  0.0000,  0.8705,  0.5032,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.2000, -0.3000,  0.0000,  0.0000,  0.8000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-0.9350,  0.2727,  0.0000,  0.0000, -1.8277,  0.4276,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.2000,  0.0000,  0.0000, -1.0000,  0.4000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.3509, -0.2210,  0.0000,  0.0000, -0.7694,  0.7672,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.4000, -0.3000,  0.0000,  0.0000, -0.8000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 1: [tensor([[ 0.2838, -0.2826, -0.1000,  0.1000,  0.8630,  0.5107,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.9425,  0.2802, -0.1000,  0.1000, -1.8352,  0.4351,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.3584, -0.2135, -0.1000,  0.1000, -0.7769,  0.7747,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0169], device='cuda:0'), tensor([-0.0169], device='cuda:0'), tensor([-0.0169], device='cuda:0')]
# Step 2 of Episode 0
# obs agent 0: tensor([[ 0.2838, -0.2826, -0.1000,  0.1000,  0.8630,  0.5107,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.2000, -0.3000, -0.2000,  0.1000,  0.8000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-0.9425,  0.2802, -0.1000,  0.1000, -1.8352,  0.4351,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.2000, -0.2000,  0.1000, -1.0000,  0.4000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.3584, -0.2135, -0.1000,  0.1000, -0.7769,  0.7747,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.4000, -0.3000, -0.2000,  0.1000, -0.8000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 2: [tensor([[ 0.2688, -0.2676, -0.1750,  0.1750,  0.8480,  0.5257,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.9575,  0.2952, -0.1750,  0.1750, -1.8502,  0.4501,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.3734, -0.1985, -0.1750,  0.1750, -0.7919,  0.7897,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0342], device='cuda:0'), tensor([-0.0342], device='cuda:0'), tensor([-0.0342], device='cuda:0')]
# Step 3 of Episode 0
# obs agent 0: tensor([[ 0.2688, -0.2676, -0.1750,  0.1750,  0.8480,  0.5257,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.2000, -0.3000, -0.2000,  0.1000,  0.8000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-0.9575,  0.2952, -0.1750,  0.1750, -1.8502,  0.4501,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.2000, -0.2000,  0.1000, -1.0000,  0.4000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.3734, -0.1985, -0.1750,  0.1750, -0.7919,  0.7897,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.4000, -0.2000, -0.2000,  0.1000, -0.8000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 3: [tensor([[ 0.2482, -0.2469, -0.2312,  0.2312,  0.8274,  0.5463,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.9781,  0.3158, -0.2312,  0.2312, -1.8708,  0.4708,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.3940, -0.1779, -0.2312,  0.2312, -0.8125,  0.8103,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0479], device='cuda:0'), tensor([-0.0479], device='cuda:0'), tensor([-0.0479], device='cuda:0')]
# Step 4 of Episode 0
# obs agent 0: tensor([[ 0.2482, -0.2469, -0.2312,  0.2312,  0.8274,  0.5463,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.2000, -0.3000, -0.3000,  0.2000,  0.8000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-0.9781,  0.3158, -0.2312,  0.2312, -1.8708,  0.4708,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.3000, -0.3000,  0.2000, -1.0000,  0.4000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.3940, -0.1779, -0.2312,  0.2312, -0.8125,  0.8103,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.4000, -0.2000, -0.3000,  0.2000, -0.9000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 4: [tensor([[ 0.2233, -0.2221, -0.2734,  0.2734,  0.8026,  0.5711,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.0029,  0.3407, -0.2734,  0.2734, -1.8957,  0.4956,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.4189, -0.1531, -0.2734,  0.2734, -0.8374,  0.8351,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0589], device='cuda:0'), tensor([-0.0589], device='cuda:0'), tensor([-0.0589], device='cuda:0')]
# Step 5 of Episode 0
# obs agent 0: tensor([[ 0.2233, -0.2221, -0.2734,  0.2734,  0.8026,  0.5711,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.2000, -0.3000, -0.3000,  0.2000,  0.8000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.0029,  0.3407, -0.2734,  0.2734, -1.8957,  0.4956,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.3000, -0.3000,  0.2000, -1.0000,  0.4000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.4189, -0.1531, -0.2734,  0.2734, -0.8374,  0.8351,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.5000, -0.2000, -0.3000,  0.2000, -0.9000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 5: [tensor([[ 0.1953, -0.1941, -0.3051,  0.3051,  0.7746,  0.5992,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.0310,  0.3687, -0.3051,  0.3051, -1.9237,  0.5236,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.4469, -0.1251, -0.3051,  0.3051, -0.8654,  0.8631,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0681], device='cuda:0'), tensor([-0.0681], device='cuda:0'), tensor([-0.0681], device='cuda:0')]
# Step 6 of Episode 0
# obs agent 0: tensor([[ 0.1953, -0.1941, -0.3051,  0.3051,  0.7746,  0.5992,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.1000, -0.2000, -0.4000,  0.3000,  0.7000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.0310,  0.3687, -0.3051,  0.3051, -1.9237,  0.5236,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.3000, -0.4000,  0.3000, -1.0000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.4469, -0.1251, -0.3051,  0.3051, -0.8654,  0.8631,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.5000, -0.2000, -0.4000,  0.3000, -0.9000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 6: [tensor([[ 0.1650, -0.1637, -0.3288,  0.3288,  0.7442,  0.6295,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.0613,  0.3991, -0.3288,  0.3288, -1.9541,  0.5540,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.4773, -0.0947, -0.3288,  0.3288, -0.8958,  0.8935,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0759], device='cuda:0'), tensor([-0.0759], device='cuda:0'), tensor([-0.0759], device='cuda:0')]
# Step 7 of Episode 0
# obs agent 0: tensor([[ 0.1650, -0.1637, -0.3288,  0.3288,  0.7442,  0.6295,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.1000, -0.2000, -0.4000,  0.3000,  0.7000,  0.6000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.0613,  0.3991, -0.3288,  0.3288, -1.9541,  0.5540,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.3000, -0.4000,  0.3000, -1.0000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.4773, -0.0947, -0.3288,  0.3288, -0.8958,  0.8935,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.5000, -0.1000, -0.4000,  0.3000, -0.9000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 7: [tensor([[ 0.1328, -0.1315, -0.3466,  0.3466,  0.7120,  0.6617,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.0935,  0.4312, -0.3466,  0.3466, -1.9862,  0.5862,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.5094, -0.0625, -0.3466,  0.3466, -0.9279,  0.9257,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0826], device='cuda:0'), tensor([-0.0826], device='cuda:0'), tensor([-0.0826], device='cuda:0')]
# Step 8 of Episode 0
# obs agent 0: tensor([[ 0.1328, -0.1315, -0.3466,  0.3466,  0.7120,  0.6617,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.1000, -0.2000, -0.4000,  0.3000,  0.7000,  0.6000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.0935,  0.4312, -0.3466,  0.3466, -1.9862,  0.5862,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.4000, -0.4000,  0.3000, -1.0000,  0.5000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.5094, -0.0625, -0.3466,  0.3466, -0.9279,  0.9257,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.6000, -0.1000, -0.4000,  0.3000, -1.0000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 8: [tensor([[ 0.0993, -0.0980, -0.3600,  0.3600,  0.6785,  0.6952,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.1270,  0.4647, -0.3600,  0.3600, -2.0197,  0.6196,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.5429, -0.0290, -0.3600,  0.3600, -0.9614,  0.9592,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0885], device='cuda:0'), tensor([-0.0885], device='cuda:0'), tensor([-0.0885], device='cuda:0')]
# Step 9 of Episode 0
# obs agent 0: tensor([[ 0.0993, -0.0980, -0.3600,  0.3600,  0.6785,  0.6952,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.0000, -0.1000, -0.4000,  0.3000,  0.6000,  0.6000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.1270,  0.4647, -0.3600,  0.3600, -2.0197,  0.6196,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.4000, -0.4000,  0.3000, -1.0000,  0.6000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.5429, -0.0290, -0.3600,  0.3600, -0.9614,  0.9592,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.6000, -0.1000, -0.4000,  0.3000, -1.0000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 9: [tensor([[ 0.0648, -0.0635, -0.3700,  0.3700,  0.6440,  0.7297,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.1615,  0.4992, -0.3700,  0.3700, -2.0542,  0.6541,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.5774,  0.0055, -0.3700,  0.3700, -0.9959,  0.9937,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0938], device='cuda:0'), tensor([-0.0938], device='cuda:0'), tensor([-0.0938], device='cuda:0')]
# Step 10 of Episode 0
# obs agent 0: tensor([[ 0.0648, -0.0635, -0.3700,  0.3700,  0.6440,  0.7297,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.0000, -0.1000, -0.4000,  0.3000,  0.6000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.1615,  0.4992, -0.3700,  0.3700, -2.0542,  0.6541,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.4000, -0.4000,  0.3000, -1.0000,  0.6000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.5774,  0.0055, -0.3700,  0.3700, -0.9959,  0.9937,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.6000,  0.0000, -0.4000,  0.3000, -1.0000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 10: [tensor([[ 0.0296, -0.0283, -0.3775,  0.3775,  0.6088,  0.7649,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.1967,  0.5345, -0.3775,  0.3775, -2.0895,  0.6894,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.6127,  0.0407, -0.3775,  0.3775, -1.0312,  1.0289,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.0986], device='cuda:0'), tensor([-0.0986], device='cuda:0'), tensor([-0.0986], device='cuda:0')]
# Step 11 of Episode 0
# obs agent 0: tensor([[ 0.0296, -0.0283, -0.3775,  0.3775,  0.6088,  0.7649,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[ 0.0000, -0.1000, -0.4000,  0.3000,  0.6000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.1967,  0.5345, -0.3775,  0.3775, -2.0895,  0.6894,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.5000, -0.4000,  0.3000, -1.0000,  0.6000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.6127,  0.0407, -0.3775,  0.3775, -1.0312,  1.0289,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.7000,  0.0000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 11: [tensor([[-0.0063,  0.0075, -0.3831,  0.3831,  0.5730,  0.8007,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.2325,  0.5703, -0.3831,  0.3831, -2.1253,  0.7252,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.6485,  0.0765, -0.3831,  0.3831, -1.0670,  1.0647,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1030], device='cuda:0'), tensor([-0.1030], device='cuda:0'), tensor([-0.1030], device='cuda:0')]
# Step 12 of Episode 0
# obs agent 0: tensor([[-0.0063,  0.0075, -0.3831,  0.3831,  0.5730,  0.8007,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.1000,  0.0000, -0.4000,  0.3000,  0.5000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.2325,  0.5703, -0.3831,  0.3831, -2.1253,  0.7252,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.5000, -0.4000,  0.3000, -1.0000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.6485,  0.0765, -0.3831,  0.3831, -1.0670,  1.0647,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.7000,  0.0000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 12: [tensor([[-0.0425,  0.0437, -0.3873,  0.3873,  0.5367,  0.8370,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.2688,  0.6065, -0.3873,  0.3873, -2.1615,  0.7614,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.6847,  0.1128, -0.3873,  0.3873, -1.1032,  1.1010,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1070], device='cuda:0'), tensor([-0.1070], device='cuda:0'), tensor([-0.1070], device='cuda:0')]
# Step 13 of Episode 0
# obs agent 0: tensor([[-0.0425,  0.0437, -0.3873,  0.3873,  0.5367,  0.8370,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.1000,  0.0000, -0.4000,  0.3000,  0.5000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.2688,  0.6065, -0.3873,  0.3873, -2.1615,  0.7614,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.6000, -0.4000,  0.3000, -1.0000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.6847,  0.1128, -0.3873,  0.3873, -1.1032,  1.1010,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.7000,  0.1000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 13: [tensor([[-0.0790,  0.0803, -0.3905,  0.3905,  0.5002,  0.8735,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.3053,  0.6431, -0.3905,  0.3905, -2.1981,  0.7980,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.7213,  0.1493, -0.3905,  0.3905, -1.1398,  1.1375,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1107], device='cuda:0'), tensor([-0.1107], device='cuda:0'), tensor([-0.1107], device='cuda:0')]
# Step 14 of Episode 0
# obs agent 0: tensor([[-0.0790,  0.0803, -0.3905,  0.3905,  0.5002,  0.8735,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.1000,  0.0000, -0.4000,  0.3000,  0.5000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.3053,  0.6431, -0.3905,  0.3905, -2.1981,  0.7980,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.6000, -0.4000,  0.3000, -1.0000,  0.7000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.7213,  0.1493, -0.3905,  0.3905, -1.1398,  1.1375,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.8000,  0.1000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 14: [tensor([[-0.1158,  0.1171, -0.3929,  0.3929,  0.4634,  0.9103,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.3421,  0.6799, -0.3929,  0.3929, -2.2348,  0.8348,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.7581,  0.1861, -0.3929,  0.3929, -1.1765,  1.1743,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1141], device='cuda:0'), tensor([-0.1141], device='cuda:0'), tensor([-0.1141], device='cuda:0')]
# Step 15 of Episode 0
# obs agent 0: tensor([[-0.1158,  0.1171, -0.3929,  0.3929,  0.4634,  0.9103,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.2000,  0.1000, -0.4000,  0.3000,  0.4000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.3421,  0.6799, -0.3929,  0.3929, -2.2348,  0.8348,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.6000, -0.4000,  0.3000, -1.0000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.7581,  0.1861, -0.3929,  0.3929, -1.1765,  1.1743,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.8000,  0.1000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 15: [tensor([[-0.1528,  0.1540, -0.3947,  0.3947,  0.4264,  0.9473,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.3791,  0.7168, -0.3947,  0.3947, -2.2718,  0.8717,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.7950,  0.2231, -0.3947,  0.3947, -1.2135,  1.2113,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1173], device='cuda:0'), tensor([-0.1173], device='cuda:0'), tensor([-0.1173], device='cuda:0')]
# Step 16 of Episode 0
# obs agent 0: tensor([[-0.1528,  0.1540, -0.3947,  0.3947,  0.4264,  0.9473,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.2000,  0.1000, -0.4000,  0.3000,  0.4000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.3791,  0.7168, -0.3947,  0.3947, -2.2718,  0.8717,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.7000, -0.4000,  0.3000, -1.0000,  0.8000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.7950,  0.2231, -0.3947,  0.3947, -1.2135,  1.2113,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.8000,  0.2000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 16: [tensor([[-0.1899,  0.1911, -0.3960,  0.3960,  0.3893,  0.9844,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.4162,  0.7539, -0.3960,  0.3960, -2.3089,  0.9088,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.8321,  0.2602, -0.3960,  0.3960, -1.2506,  1.2484,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1202], device='cuda:0'), tensor([-0.1202], device='cuda:0'), tensor([-0.1202], device='cuda:0')]
# Step 17 of Episode 0
# obs agent 0: tensor([[-0.1899,  0.1911, -0.3960,  0.3960,  0.3893,  0.9844,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.2000,  0.1000, -0.4000,  0.3000,  0.3000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.4162,  0.7539, -0.3960,  0.3960, -2.3089,  0.9088,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.7000, -0.4000,  0.3000, -1.0000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.8321,  0.2602, -0.3960,  0.3960, -1.2506,  1.2484,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.9000,  0.2000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 17: [tensor([[-0.2271,  0.2283, -0.3970,  0.3970,  0.3521,  1.0216,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.4534,  0.7911, -0.3970,  0.3970, -2.3461,  0.9460,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.8693,  0.2974, -0.3970,  0.3970, -1.2878,  1.2856,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1229], device='cuda:0'), tensor([-0.1229], device='cuda:0'), tensor([-0.1229], device='cuda:0')]
# Step 18 of Episode 0
# obs agent 0: tensor([[-0.2271,  0.2283, -0.3970,  0.3970,  0.3521,  1.0216,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.3000,  0.2000, -0.4000,  0.3000,  0.3000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.4534,  0.7911, -0.3970,  0.3970, -2.3461,  0.9460,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  0.7000, -0.4000,  0.3000, -1.0000,  0.9000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-0.8693,  0.2974, -0.3970,  0.3970, -1.2878,  1.2856,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-0.9000,  0.2000, -0.4000,  0.3000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 18: [tensor([[-0.2644,  0.2656, -0.3977,  0.3977,  0.3149,  1.0589,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-1.4907,  0.8284, -0.3977,  0.3977, -2.3834,  0.9833,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-0.9066,  0.3346, -0.3977,  0.3977, -1.3251,  1.3228,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1254], device='cuda:0'), tensor([-0.1254], device='cuda:0'), tensor([-0.1254], device='cuda:0')]
# Step 19 of Episode 0
# obs agent 0: tensor([[-0.2644,  0.2656, -0.3977,  0.3977,  0.3149,  1.0589,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-0.3000,  0.2000, -0.4000,  0.3000,  0.3000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-1.4907,  0.8284, -0.3977,  0.3977, -2.3834,  0.9833,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
# ...
# Step 95 of Episode 0
# obs agent 0: tensor([[-3.1137,  3.1149, -0.4000,  0.4000, -2.5345,  3.9082,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-4.3400,  3.6777, -0.4000,  0.4000, -5.2327,  3.8326,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-3.7559,  3.1840, -0.4000,  0.4000, -4.1744,  4.1722,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 95: [tensor([[-3.1512,  3.1524, -0.4000,  0.4000, -2.5720,  3.9457,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-4.3775,  3.7152, -0.4000,  0.4000, -5.2702,  3.8701,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-3.7934,  3.2215, -0.4000,  0.4000, -4.2119,  4.2097,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1573], device='cuda:0'), tensor([-0.1573], device='cuda:0'), tensor([-0.1573], device='cuda:0')]
# Step 96 of Episode 0
# obs agent 0: tensor([[-3.1512,  3.1524, -0.4000,  0.4000, -2.5720,  3.9457,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-4.3775,  3.7152, -0.4000,  0.4000, -5.2702,  3.8701,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-3.7934,  3.2215, -0.4000,  0.4000, -4.2119,  4.2097,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 96: [tensor([[-3.1887,  3.1899, -0.4000,  0.4000, -2.6095,  3.9832,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-4.4150,  3.7527, -0.4000,  0.4000, -5.3077,  3.9076,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-3.8309,  3.2590, -0.4000,  0.4000, -4.2494,  4.2472,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1574], device='cuda:0'), tensor([-0.1574], device='cuda:0'), tensor([-0.1574], device='cuda:0')]
# Step 97 of Episode 0
# obs agent 0: tensor([[-3.1887,  3.1899, -0.4000,  0.4000, -2.6095,  3.9832,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-4.4150,  3.7527, -0.4000,  0.4000, -5.3077,  3.9076,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-3.8309,  3.2590, -0.4000,  0.4000, -4.2494,  4.2472,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 97: [tensor([[-3.2262,  3.2274, -0.4000,  0.4000, -2.6470,  4.0207,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-4.4525,  3.7902, -0.4000,  0.4000, -5.3452,  3.9451,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-3.8684,  3.2965, -0.4000,  0.4000, -4.2869,  4.2847,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1574], device='cuda:0'), tensor([-0.1574], device='cuda:0'), tensor([-0.1574], device='cuda:0')]
# Step 98 of Episode 0
# obs agent 0: tensor([[-3.2262,  3.2274, -0.4000,  0.4000, -2.6470,  4.0207,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-4.4525,  3.7902, -0.4000,  0.4000, -5.3452,  3.9451,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-3.8684,  3.2965, -0.4000,  0.4000, -4.2869,  4.2847,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 98: [tensor([[-3.2637,  3.2649, -0.4000,  0.4000, -2.6845,  4.0582,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-4.4900,  3.8277, -0.4000,  0.4000, -5.3827,  3.9826,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-3.9059,  3.3340, -0.4000,  0.4000, -4.3244,  4.3222,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1574], device='cuda:0'), tensor([-0.1574], device='cuda:0'), tensor([-0.1574], device='cuda:0')]
# Step 99 of Episode 0
# obs agent 0: tensor([[-3.2637,  3.2649, -0.4000,  0.4000, -2.6845,  4.0582,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-4.4900,  3.8277, -0.4000,  0.4000, -5.3827,  3.9826,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-3.9059,  3.3340, -0.4000,  0.4000, -4.3244,  4.3222,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 99: [tensor([[-3.3012,  3.3024, -0.4000,  0.4000, -2.7220,  4.0957,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-4.5275,  3.8652, -0.4000,  0.4000, -5.4202,  4.0201,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-3.9434,  3.3715, -0.4000,  0.4000, -4.3619,  4.3597,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1575], device='cuda:0'), tensor([-0.1575], device='cuda:0'), tensor([-0.1575], device='cuda:0')]
# Step 100 of Episode 0
# obs agent 0: tensor([[-3.3012,  3.3024, -0.4000,  0.4000, -2.7220,  4.0957,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 0: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 0: tensor([[10]], device='cuda:0')
# obs agent 1: tensor([[-4.5275,  3.8652, -0.4000,  0.4000, -5.4202,  4.0201,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 1: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 1: tensor([[10]], device='cuda:0')
# obs agent 2: tensor([[-3.9434,  3.3715, -0.4000,  0.4000, -4.3619,  4.3597,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')
# discrete obs of agent 2: tensor([[-1.0000,  1.0000, -0.5000,  0.4000, -1.0000,  1.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000]], device='cuda:0', dtype=torch.float64)
# action agent 2: tensor([[10]], device='cuda:0')
# obs agent after step 100: [tensor([[-3.3387,  3.3399, -0.4000,  0.4000, -2.7595,  4.1332,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-4.5650,  3.9027, -0.4000,  0.4000, -5.4577,  4.0576,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0'), tensor([[-3.9809,  3.4090, -0.4000,  0.4000, -4.3994,  4.3972,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  1.0000,  0.0000,  1.0000,  0.0000]],
#        device='cuda:0')]
# rews agent: [tensor([-0.1575], device='cuda:0'), tensor([-0.1575], device='cuda:0'), tensor([-0.1575], device='cuda:0')]
# It took: 3.680605173110962s for 100 steps across 1 episodes of 1 parallel environments on device cuda for navigation_comm scenario.
# MoviePy - Building file navigation_comm.gif with imageio.
# <img src="navigation_comm.gif">
