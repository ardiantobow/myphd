# %%
import time
import torch
from vmas import make_env
from vmas.simulator.core import Agent
from vmas.simulator.scenario import BaseScenario
from typing import Union
from moviepy.editor import ImageSequenceClip
from IPython.display import HTML, display as ipython_display
import numpy as np
import matplotlib.pyplot as plt
from gym.spaces import Discrete 

class QLearningAgent:
    def __init__(self, env, agent_id, alpha=0.1, gamma=0.99, epsilon=0.1, communication_weight=0.5):
        self.alpha = alpha  # Learning rate
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration rate
        self.q_table = {}
        self.env = env
        self.agent_id = agent_id
        self.communication_weight = communication_weight  # Weight parameter for incorporating messages
        self.action_count = 0  # Initialize action count to 0

    def get_action(self, agent, env, agent_id, agent_obs):
        # Increment action count whenever get_action is called
        self.action_count += 1

        obs_tuple = tuple(agent_obs.cpu().numpy().flatten())
        obs_tuple_agent = obs_tuple[0:5]
        if not agent.silent:
            obs_tuple_comm = obs_tuple[7]
        
        # print(f"obs_tuple: {obs_tuple}")

        if obs_tuple_agent not in self.q_table:
            self.q_table[obs_tuple_agent] = np.zeros(self.env.action_space[self.agent_id].n)
            # print(f"q-table: {self.q_table[obs_tuple_agent]}")
        
        if np.random.rand() < self.epsilon:
            # physical_action = (np.random.randint(self.env.action_space[self.agent_id].n),)  # Explore: random action
            physical_action = env.get_random_action(agent)

        else:
            physical_action = (np.argmax(self.q_table[obs_tuple_agent]),)  # Exploit: best known action
        
        # print(f"physical_action: {physical_action}")
        
        # Construct the message with all states and their max Q-values
        # comm_action = []
        # for state, q_vals in self.q_table.items():
        #     max_action = np.argmax(q_vals).item()
        #     max_q_val = np.max(q_vals).item()
        #     comm_action.extend([max_action, max_q_val])

        if agent.silent:
            action = torch.tensor(physical_action, device=self.env.device)
        else:
            physical_action_tensor = torch.tensor(physical_action, device=self.env.device)
            comm_action_tensor = torch.tensor([obs_tuple_comm], device=self.env.device)  # Adding a dimension to obs_tuple_comm
            
            if agent_id == 1:
                physical_action_tensor = torch.tensor(comm_action_tensor, device=self.env.device)
            # else:
            #     physical_action_tensor = torch.tensor(comm_action_tensor, device=self.env.device) # agent 1 follow the agent 0 action

           
            action = torch.cat([physical_action_tensor, physical_action_tensor], dim=0)

        # print(f"agent_id {agent_id} qtable: {self.q_table[obs_tuple_agent]}")
        # print(f"action space: {self.env.action_space[self.agent_id].n}")
        return action.unsqueeze(0)

    

    def update_q_table(self, obs, action, reward, next_obs):
        obs_tuple = tuple(obs.cpu().numpy().flatten())
        next_obs_tuple = tuple(next_obs.cpu().numpy().flatten())
        
        if isinstance(self.env.action_space[self.agent_id], Discrete):
            action_space_size = self.env.action_space[self.agent_id].n
        else:
            raise ValueError("This Q-learning implementation requires a discrete action space.")

        if obs_tuple not in self.q_table:
            self.q_table[obs_tuple] = np.zeros(action_space_size)
        if next_obs_tuple not in self.q_table:
            self.q_table[next_obs_tuple] = np.zeros(action_space_size)

        best_next_action = np.argmax(self.q_table[next_obs_tuple])
        td_target = reward + self.gamma * self.q_table[next_obs_tuple][best_next_action]

        # Ensure `action` is a valid integer index
        if isinstance(action, torch.Tensor):
            action = action[0, 0].item()  # Extract the first element from the 2D tensor

        action = int(action)  # Explicitly convert to integer

        td_error = td_target - self.q_table[obs_tuple][action]
        self.q_table[obs_tuple][action] += self.alpha * td_error




class VMASEnvRunner:
    def __init__(
        self,
        render: bool,
        num_envs: int,
        num_episodes: int,
        max_steps_per_episode: int,
        device: str,
        scenario: Union[str, BaseScenario],
        continuous_actions: bool,
        random_action: bool,
        obs_discrete: bool = False,
        **kwargs
    ):
        self.render = render
        self.num_envs = num_envs
        self.num_episodes = num_episodes
        self.max_steps_per_episode = max_steps_per_episode
        self.device = device
        self.scenario = scenario
        self.continuous_actions = continuous_actions
        self.random_action = random_action
        self.obs_discrete = obs_discrete
        self.kwargs = kwargs
        self.frame_list = []  # Initialize frame list
        self.q_learning_agents = []
        self.rewards_history = []  # Initialize rewards history
        # self.action_counts = {i: [] for i in range(self.num_envs)}  # Dictionary to store action counts for each agent

    def discretize(self, data, bins):
        bins = np.array(bins)
        if np.isscalar(data):
            bin_indices = np.digitize([data], bins)[0]
            bin_values = bins[bin_indices - 1] if bin_indices > 0 else bins[0]
            return bin_indices, bin_values
        else:
            bin_indices = np.digitize(data, bins)
            bin_values = [bins[index - 1] if index > 0 else bins[0] for index in bin_indices]
            return bin_indices, bin_values

    def discretize_tensor_slice(self, tensor_slice, bins):
        indices = []
        values = []
        for row in tensor_slice:
            row_indices = []
            row_values = []
            for item in row:
                bin_idx, bin_val = self.discretize(item.item(), bins)
                row_indices.append(bin_idx)
                row_values.append(bin_val)
            indices.append(row_indices)
            values.append(row_values)
        return torch.tensor(indices, device=tensor_slice.device), torch.tensor(values, device=tensor_slice.device)

    def _get_deterministic_obs(self, env, observation):
        # print(f"observasi asli: {observation}")
        pos_bins = np.linspace(-1, 1, num=21)
        vel_bins = np.linspace(-1, 1, num=21)
        lidar_bins = np.linspace(0, 1, num=21)

        pos = observation[:, :2]
        vel = observation[:, 2:4]
        goal_pose = observation[:, 4:6]
        sensor_data = observation[:, 6:18]
        comms_data = observation[:, 6:]

        # if(sensor_data is None):
        #     comms_data = observation[:, 6:]
        # else:
        #     comms_data = observation[:, 18:]

        discrete_pos_indices, discrete_pos_values = self.discretize_tensor_slice(pos, pos_bins)
        discrete_vel_indices, discrete_vel_values = self.discretize_tensor_slice(vel, vel_bins)
        discrete_goal_pose_indices, discrete_goal_pose_values = self.discretize_tensor_slice(goal_pose, pos_bins)
        discrete_sensor_data_indices, discrete_sensor_data_values = self.discretize_tensor_slice(sensor_data, lidar_bins)

        # concatenated_tensor_indices = torch.cat(
        #     [discrete_pos_indices, discrete_vel_indices, discrete_goal_pose_indices, discrete_sensor_data_indices],
        #     dim=1
        # )
        concatenated_tensor_values = torch.cat(
            [discrete_pos_values, discrete_vel_values, discrete_goal_pose_values, discrete_sensor_data_values, comms_data],
            dim=1
        )
        # print(f"comsssss dataaaa: {comms_data}")
        return concatenated_tensor_values

    def _get_deterministic_action(self, agent: Agent, env, agent_id, agent_obs):
        if self.continuous_actions:
            if agent.silent:
                action = torch.tensor([[-1, 0.5]], device=env.device)
            else:
                if agent_id == 0:
                    action = torch.tensor([[-1, 0.5, 2]], device=env.device)
                else:
                    action = torch.tensor([[-1, 0.5, 1]], device=env.device)
        else:
            action = self.q_learning_agents[agent_id].get_action(agent,env, agent_id, agent_obs)

        return action.clone()

    def generate_gif(self, scenario_name):
        fps = 25
        clip = ImageSequenceClip(self.frame_list, fps=fps)
        clip.write_gif(f'{scenario_name}.gif', fps=fps)
        return HTML(f'<img src="{scenario_name}.gif">')

    def plot_rewards(self):
        plt.figure(figsize=(12, 6))
        for agent_id, rewards in enumerate(zip(*self.rewards_history)):
            plt.plot(rewards, label=f'Agent {agent_id}')
        plt.xlabel('Time Steps')
        plt.ylabel('Rewards')
        plt.title('Rewards per Time Step for Each Agent')
        plt.legend()
        plt.show()

    def plot_action_distribution(self):
        plt.figure(figsize=(12, 6))
        for agent_id, counts in self.action_counts.items():
            plt.hist(counts, bins=range(max(counts) + 2), alpha=0.5, label=f'Agent {agent_id}')
        plt.xlabel('Number of Actions')
        plt.ylabel('Frequency')
        plt.title('Distribution of Number of Actions Taken by Each Agent')
        plt.legend()
        plt.show()


    def run_vmas_env(self):
        scenario_name = self.scenario if isinstance(self.scenario, str) else self.scenario.__class__.__name__

        env = make_env(
            scenario=self.scenario,
            num_envs=self.num_envs,
            device=self.device,
            continuous_actions=self.continuous_actions,
            seed=0,
            **self.kwargs
        )

        # Initialize Q-learning agents
        for agent_id, agent in enumerate(env.agents):
            self.q_learning_agents.append(QLearningAgent(env, agent_id, communication_weight=0.5))

        init_time = time.time()
        total_steps = 0
        
        for e in range(self.num_episodes):
            print(f"Episode {e}")
            obs = env.reset()
            done = [False] * self.num_envs
            step = 0
            while not all(done) and step < self.max_steps_per_episode:
                step += 1
                total_steps += 1
                print(f"Step {step} of Episode {e}")

                actions = []
                for i, agent in enumerate(env.agents):
                    if self.obs_discrete:
                        discrete_obs = self._get_deterministic_obs(env, obs[i])
                        obs[i] = discrete_obs
                        # print(f"observation agent{i}: {obs[i]}")

                    if self.random_action:
                        action = env.get_random_action(agent)
                    else:
                        action = self._get_deterministic_action(agent, env, i, obs[i])
                    
                    print(f"Action agent{i}: {action}")

                    actions.append(action)

                     # Store action count for each agent
                    # self.action_counts[i].append(self.q_learning_agents[i].action_count)

                next_obs, rews, dones, info = env.step(actions)
                done = [done or d for done, d in zip(done, dones)]

                # Append the rewards to the rewards history
                if len(self.rewards_history) <= step:
                    self.rewards_history.append([0] * len(env.agents))
                for i, rew in enumerate(rews):
                    self.rewards_history[step-1][i] = rew.item()

                for i, agent in enumerate(env.agents):
                    self.q_learning_agents[i].update_q_table(obs[i], actions[i], rews[i], next_obs[i])

                obs = next_obs

                if self.render:
                    frame = env.render(
                        mode="rgb_array",
                        agent_index_focus=None,
                    )
                    self.frame_list.append(frame)

        total_time = time.time() - init_time
        print(
            f"It took: {total_time}s for {total_steps} steps across {self.num_episodes} episodes of {self.num_envs} parallel environments on device {self.device} "
            f"for {scenario_name} scenario."
        )

        # Plot rewards after all episodes are done
        self.plot_rewards()
        # self.plot_action_distribution

if __name__ == "__main__":
    scenario_name = "navigation_comm"

    env_runner = VMASEnvRunner(
        render=True,
        num_envs=1,
        num_episodes=1,
        max_steps_per_episode=1000,
        device="cuda",
        scenario=scenario_name,
        continuous_actions=False,
        random_action=False,
        obs_discrete=True,
        n_agents=2,
        agents_with_same_goal=2,
        collisions=False,
        shared_rew=False,
    )
    env_runner.run_vmas_env()
    ipython_display(env_runner.generate_gif(scenario_name))
# Out:
# Episode 0
# Step 1 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 2 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 3 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 4 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 5 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 6 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 7 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 8 of Episode 0
# Action agent0: tensor([[5, 5]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 9 of Episode 0
# Action agent0: tensor([[4, 4]], device='cuda:0')
# Action agent1: tensor([[5., 5.]], device='cuda:0', dtype=torch.float64)
# Step 10 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[4., 4.]], device='cuda:0', dtype=torch.float64)
# Step 11 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 12 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 13 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 14 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 15 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 16 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 17 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 18 of Episode 0
# Action agent0: tensor([[7, 7]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 19 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[7., 7.]], device='cuda:0', dtype=torch.float64)
# Step 20 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 21 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 22 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 23 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 24 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 25 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 26 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 27 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 28 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 29 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 30 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 31 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 32 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 33 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 34 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 35 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 36 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 37 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 38 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 39 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 40 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 41 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 42 of Episode 0
# Action agent0: tensor([[6, 6]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 43 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[6., 6.]], device='cuda:0', dtype=torch.float64)
# Step 44 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 45 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 46 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 47 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 48 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 49 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 50 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 51 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 52 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 53 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 54 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 55 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 56 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 57 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 58 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 59 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 60 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 61 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 62 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 63 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 64 of Episode 0
# Action agent0: tensor([[3, 3]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 65 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[3., 3.]], device='cuda:0', dtype=torch.float64)
# Step 66 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 67 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 68 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 69 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 70 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 71 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 72 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 73 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 74 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 75 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 76 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 77 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 78 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 79 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 80 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 81 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 82 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 83 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 84 of Episode 0
# Action agent0: tensor([[6, 6]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 85 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[6., 6.]], device='cuda:0', dtype=torch.float64)
# Step 86 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 87 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 88 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 89 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 90 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 91 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 92 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 93 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 94 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 95 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 96 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 97 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 98 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 99 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 100 of Episode 0
# Action agent0: tensor([[5, 5]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 101 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[5., 5.]], device='cuda:0', dtype=torch.float64)
# Step 102 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 103 of Episode 0
# Action agent0: tensor([[6, 6]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 104 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[6., 6.]], device='cuda:0', dtype=torch.float64)
# Step 105 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 106 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 107 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 108 of Episode 0
# Action agent0: tensor([[8, 8]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 109 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[8., 8.]], device='cuda:0', dtype=torch.float64)
# Step 110 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 111 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 112 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 113 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 114 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 115 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 116 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 117 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 118 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 119 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 120 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 121 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 122 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 123 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 124 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 125 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 126 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 127 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 128 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 129 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 130 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 131 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 132 of Episode 0
# Action agent0: tensor([[1, 1]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 133 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[1., 1.]], device='cuda:0', dtype=torch.float64)
# Step 134 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 135 of Episode 0
# Action agent0: tensor([[1, 1]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 136 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[1., 1.]], device='cuda:0', dtype=torch.float64)
# Step 137 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 138 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 139 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 140 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 141 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 142 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 143 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 144 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 145 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 146 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 147 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 148 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 149 of Episode 0
# Action agent0: tensor([[3, 3]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 150 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[3., 3.]], device='cuda:0', dtype=torch.float64)
# Step 151 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 152 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 153 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 154 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 155 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 156 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 157 of Episode 0
# Action agent0: tensor([[2, 2]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 158 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[2., 2.]], device='cuda:0', dtype=torch.float64)
# Step 159 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 160 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 161 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 162 of Episode 0
# Action agent0: tensor([[1, 1]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 163 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[1., 1.]], device='cuda:0', dtype=torch.float64)
# Step 164 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 165 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 166 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 167 of Episode 0
# Action agent0: tensor([[4, 4]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 168 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[4., 4.]], device='cuda:0', dtype=torch.float64)
# Step 169 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 170 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 171 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 172 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 173 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 174 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 175 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 176 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 177 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 178 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 179 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 180 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 181 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 182 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 183 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 184 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 185 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 186 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 187 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 188 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 189 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 190 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 191 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 192 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 193 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 194 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 195 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 196 of Episode 0
# Action agent0: tensor([[6, 6]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 197 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[6., 6.]], device='cuda:0', dtype=torch.float64)
# Step 198 of Episode 0
# Action agent0: tensor([[8, 8]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 199 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[8., 8.]], device='cuda:0', dtype=torch.float64)
# Step 200 of Episode 0
# Action agent0: tensor([[2, 2]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 201 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[2., 2.]], device='cuda:0', dtype=torch.float64)
# Step 202 of Episode 0
# Action agent0: tensor([[8, 8]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 203 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[8., 8.]], device='cuda:0', dtype=torch.float64)
# Step 204 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 205 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 206 of Episode 0
# Action agent0: tensor([[2, 2]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 207 of Episode 0
# Action agent0: tensor([[8, 8]], device='cuda:0')
# Action agent1: tensor([[2., 2.]], device='cuda:0', dtype=torch.float64)
# Step 208 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[8., 8.]], device='cuda:0', dtype=torch.float64)
# Step 209 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 210 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 211 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 212 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 213 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 214 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 215 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 216 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 217 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 218 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 219 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 220 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 221 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 222 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 223 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 224 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 225 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 226 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 227 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 228 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 229 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 230 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 231 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 232 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 233 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 234 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 235 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 236 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 237 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 238 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 239 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 240 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 241 of Episode 0
# Action agent0: tensor([[3, 3]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 242 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[3., 3.]], device='cuda:0', dtype=torch.float64)
# Step 243 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 244 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 245 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 246 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 247 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 248 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 249 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 250 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 251 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 252 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 253 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 254 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 255 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 256 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 257 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 258 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 259 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 260 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 261 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 262 of Episode 0
# Action agent0: tensor([[6, 6]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 263 of Episode 0
# Action agent0: tensor([[8, 8]], device='cuda:0')
# Action agent1: tensor([[6., 6.]], device='cuda:0', dtype=torch.float64)
# Step 264 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[8., 8.]], device='cuda:0', dtype=torch.float64)
# Step 265 of Episode 0
# Action agent0: tensor([[3, 3]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 266 of Episode 0
# Action agent0: tensor([[3, 3]], device='cuda:0')
# Action agent1: tensor([[3., 3.]], device='cuda:0', dtype=torch.float64)
# Step 267 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[3., 3.]], device='cuda:0', dtype=torch.float64)
# Step 268 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 269 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 270 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 271 of Episode 0
# Action agent0: tensor([[8, 8]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 272 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[8., 8.]], device='cuda:0', dtype=torch.float64)
# Step 273 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 274 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 275 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 276 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 277 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 278 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 279 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 280 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 281 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 282 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 283 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 284 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 285 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 286 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 287 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 288 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 289 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 290 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 291 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 292 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 293 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 294 of Episode 0
# Action agent0: tensor([[6, 6]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 295 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[6., 6.]], device='cuda:0', dtype=torch.float64)
# Step 296 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 297 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 298 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 299 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 300 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 301 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 302 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 303 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 304 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 305 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 306 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 307 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 308 of Episode 0
# Action agent0: tensor([[4, 4]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 309 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[4., 4.]], device='cuda:0', dtype=torch.float64)
# Step 310 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 311 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 312 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 313 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 314 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 315 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 316 of Episode 0
# Action agent0: tensor([[4, 4]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 317 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[4., 4.]], device='cuda:0', dtype=torch.float64)
# Step 318 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 319 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 320 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 321 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 322 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 323 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 324 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 325 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 326 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 327 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 328 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 329 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 330 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 331 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 332 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 333 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 334 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 335 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 336 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 337 of Episode 0
# ...
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 891 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[5., 5.]], device='cuda:0', dtype=torch.float64)
# Step 892 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 893 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 894 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 895 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 896 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 897 of Episode 0
# Action agent0: tensor([[5, 5]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 898 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[5., 5.]], device='cuda:0', dtype=torch.float64)
# Step 899 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 900 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 901 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 902 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 903 of Episode 0
# Action agent0: tensor([[5, 5]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 904 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[5., 5.]], device='cuda:0', dtype=torch.float64)
# Step 905 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 906 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 907 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 908 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 909 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 910 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 911 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 912 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 913 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 914 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 915 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 916 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 917 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 918 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 919 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 920 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 921 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 922 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 923 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 924 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 925 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 926 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 927 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 928 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 929 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 930 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 931 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 932 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 933 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 934 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 935 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 936 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 937 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 938 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 939 of Episode 0
# Action agent0: tensor([[4, 4]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 940 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[4., 4.]], device='cuda:0', dtype=torch.float64)
# Step 941 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 942 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 943 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 944 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 945 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 946 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 947 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 948 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 949 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 950 of Episode 0
# Action agent0: tensor([[6, 6]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 951 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[6., 6.]], device='cuda:0', dtype=torch.float64)
# Step 952 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 953 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 954 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 955 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 956 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 957 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 958 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 959 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 960 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 961 of Episode 0
# Action agent0: tensor([[2, 2]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 962 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[2., 2.]], device='cuda:0', dtype=torch.float64)
# Step 963 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 964 of Episode 0
# Action agent0: tensor([[1, 1]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 965 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[1., 1.]], device='cuda:0', dtype=torch.float64)
# Step 966 of Episode 0
# Action agent0: tensor([[1, 1]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 967 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[1., 1.]], device='cuda:0', dtype=torch.float64)
# Step 968 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 969 of Episode 0
# Action agent0: tensor([[7, 7]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 970 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[7., 7.]], device='cuda:0', dtype=torch.float64)
# Step 971 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 972 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 973 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 974 of Episode 0
# Action agent0: tensor([[5, 5]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 975 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[5., 5.]], device='cuda:0', dtype=torch.float64)
# Step 976 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 977 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 978 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 979 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 980 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 981 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 982 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 983 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 984 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 985 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 986 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 987 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 988 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 989 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 990 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 991 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 992 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 993 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 994 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 995 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 996 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 997 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 998 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 999 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# Step 1000 of Episode 0
# Action agent0: tensor([[0, 0]], device='cuda:0')
# Action agent1: tensor([[0., 0.]], device='cuda:0', dtype=torch.float64)
# It took: 6.732626438140869s for 1000 steps across 1 episodes of 1 parallel environments on device cuda for navigation_comm scenario.
# MoviePy - Building file navigation_comm.gif with imageio.
