# %%
import torch
import torch.nn as nn
import torch.optim as optim
import gym

# Define Actor Network
class Actor(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, output_dim)
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.softmax(self.fc3(x))
        return x

# Define Critic Network
class Critic(nn.Module):
    def __init__(self, input_dim):
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Discounted rewards function
def discount_rewards(rewards, gamma=0.99):
    discounted_rewards = []
    running_add = 0
    for r in reversed(rewards):
        running_add = running_add * gamma + r
        discounted_rewards.insert(0, running_add)
    return discounted_rewards

# Function to compute advantages
def compute_advantages(critic, states, rewards):
    values = critic(states)
    advantages = rewards - values
    return advantages

# Initialize the environment
env = gym.make('CartPole-v1')
input_dim = env.observation_space.shape[0]
output_dim = env.action_space.n

# Initialize the actor and critic networks
actor = Actor(input_dim, output_dim)
critic = Critic(input_dim)

# Initialize the optimizers
optimizer_actor = optim.Adam(actor.parameters(), lr=0.01)
optimizer_critic = optim.Adam(critic.parameters(), lr=0.01)

# Training loop
for episode in range(100):
    state = env.reset()
    episode_reward = 0

    states = []
    actions = []
    rewards = []

    while True:
        env.render()  # Render the environment

        states.append(torch.tensor(state, dtype=torch.float32))

        action_probs = actor(torch.tensor(state, dtype=torch.float32))
        action = torch.multinomial(action_probs, num_samples=1).item()
        actions.append(action)

        next_state, reward, done, _ = env.step(action)
        rewards.append(reward)

        episode_reward += reward
        state = next_state

        if done:
            discounted_rewards = torch.tensor(discount_rewards(rewards), dtype=torch.float32)
            advantages = compute_advantages(critic, torch.stack(states), discounted_rewards)

            # Compute actor loss
            log_probs = torch.log(actor(torch.stack(states)))[range(len(actions)), actions]
            actor_loss = -(log_probs * advantages).mean()

            # Compute critic loss
            critic_loss = ((critic(torch.stack(states)).squeeze() - discounted_rewards)**2).mean()

            # Update actor and critic
            optimizer_actor.zero_grad()
            optimizer_critic.zero_grad()
            actor_loss.backward()
            critic_loss.backward()
            optimizer_actor.step()
            optimizer_critic.step()

            print("Episode: {}, Reward: {}".format(episode, episode_reward))
            break

env.close()
# Out:
# Episode: 0, Reward: 9.0
# Episode: 1, Reward: 10.0
# Episode: 2, Reward: 19.0
# Episode: 3, Reward: 13.0
# Episode: 4, Reward: 12.0
# Episode: 5, Reward: 18.0
# Episode: 6, Reward: 15.0
# Episode: 7, Reward: 17.0
# Episode: 8, Reward: 14.0
# Episode: 9, Reward: 28.0
# Episode: 10, Reward: 25.0
# Episode: 11, Reward: 32.0
# Episode: 12, Reward: 31.0
# Episode: 13, Reward: 13.0
# Episode: 14, Reward: 15.0
# Episode: 15, Reward: 17.0
# Episode: 16, Reward: 25.0
# Episode: 17, Reward: 10.0
# Episode: 18, Reward: 27.0
# Episode: 19, Reward: 15.0
# Episode: 20, Reward: 15.0
# Episode: 21, Reward: 19.0
# Episode: 22, Reward: 13.0
# Episode: 23, Reward: 15.0
# Episode: 24, Reward: 13.0
# Episode: 25, Reward: 9.0
# Episode: 26, Reward: 17.0
# Episode: 27, Reward: 25.0
# Episode: 28, Reward: 35.0
# Episode: 29, Reward: 40.0
# Episode: 30, Reward: 26.0
# Episode: 31, Reward: 61.0
# Episode: 32, Reward: 13.0
# Episode: 33, Reward: 19.0
# Episode: 34, Reward: 36.0
# Episode: 35, Reward: 43.0
# Episode: 36, Reward: 10.0
# Episode: 37, Reward: 17.0
# Episode: 38, Reward: 25.0
# Episode: 39, Reward: 31.0
# Episode: 40, Reward: 11.0
# Episode: 41, Reward: 38.0
# Episode: 42, Reward: 14.0
# Episode: 43, Reward: 15.0
# Episode: 44, Reward: 28.0
# Episode: 45, Reward: 16.0
# Episode: 46, Reward: 19.0
# Episode: 47, Reward: 49.0
# Episode: 48, Reward: 50.0
# Episode: 49, Reward: 34.0
# Episode: 50, Reward: 82.0
# Episode: 51, Reward: 24.0
# Episode: 52, Reward: 56.0
# Episode: 53, Reward: 75.0
# Episode: 54, Reward: 90.0
# Episode: 55, Reward: 27.0
# Episode: 56, Reward: 51.0
# Episode: 57, Reward: 13.0
# Episode: 58, Reward: 20.0
# Episode: 59, Reward: 38.0
# Episode: 60, Reward: 129.0
# Episode: 61, Reward: 58.0
# Episode: 62, Reward: 68.0
# Episode: 63, Reward: 99.0
# Episode: 64, Reward: 63.0
# Episode: 65, Reward: 100.0
# Episode: 66, Reward: 61.0
# Episode: 67, Reward: 102.0
# Episode: 68, Reward: 135.0
# Episode: 69, Reward: 42.0
# Episode: 70, Reward: 74.0
# Episode: 71, Reward: 116.0
# Episode: 72, Reward: 27.0
# Episode: 73, Reward: 44.0
# Episode: 74, Reward: 56.0
# Episode: 75, Reward: 44.0
# Episode: 76, Reward: 79.0
# Episode: 77, Reward: 118.0
# Episode: 78, Reward: 69.0
# Episode: 79, Reward: 92.0
# Episode: 80, Reward: 33.0
# Episode: 81, Reward: 58.0
# Episode: 82, Reward: 57.0
# Episode: 83, Reward: 159.0
# Episode: 84, Reward: 96.0
# Episode: 85, Reward: 83.0
# Episode: 86, Reward: 51.0
# Episode: 87, Reward: 92.0
# Episode: 88, Reward: 80.0
# Episode: 89, Reward: 46.0
# Episode: 90, Reward: 116.0
# Episode: 91, Reward: 121.0
# Episode: 92, Reward: 99.0
# Episode: 93, Reward: 63.0
# Episode: 94, Reward: 84.0
# Episode: 95, Reward: 122.0
# Episode: 96, Reward: 69.0
# Episode: 97, Reward: 109.0
# Episode: 98, Reward: 84.0
# Episode: 99, Reward: 128.0
