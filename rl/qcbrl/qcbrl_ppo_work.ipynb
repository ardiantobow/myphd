# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import gym
from gym.envs.registration import register
import random
from collections import deque
import matplotlib.pyplot as plt
import psutil
import pynvml
import json

# Register the custom FrozenLake environment
register(
    id='CustomRewardFrozenLake-v1',
    entry_point='gym.envs.toy_text:FrozenLakeEnv',
    kwargs={'map_name': '4x4', 'is_slippery': True},
    max_episode_steps=100,
    reward_threshold=0.78,  # Adjust the reward threshold if needed
)

# Define the custom FrozenLake environment with modified rewards
class CustomRewardFrozenLake(gym.Env):
    def __init__(self):
        self.env = gym.make("CustomRewardFrozenLake-v1")
        self.observation_space = self.env.observation_space
        self.action_space = self.env.action_space

    def step(self, action):
        state, reward, done, info = self.env.step(action)
        if reward == 0 and not done:
            reward = 0
        elif reward == 0 and done:
            reward = -5
        elif reward == 1:
            reward = 1
        return state, reward, done, info

    def reset(self):
        return self.env.reset()

    def render(self):
        self.env.render()

    def close(self):
        self.env.close()

# Define Actor Network
class Actor(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, output_dim)
        self.softmax = nn.Softmax(dim=-1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.softmax(self.fc3(x))
        return x

# Define Critic Network
class Critic(nn.Module):
    def __init__(self, input_dim):
        # print(f"Critic Input Dim: {input_dim}")
        super(Critic, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Define Experience Buffer
class ExperienceBuffer:
    def __init__(self, buffer_size):
        self.buffer = deque(maxlen=buffer_size)

    def add(self, state, action, log_prob, value, reward, done):
        self.buffer.append((state, action, log_prob, value, reward, done))

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, log_probs, values, rewards, dones = zip(*batch)
        return states, actions, log_probs, values, rewards, dones

# PPO loss function
def calculate_ppo_loss(actor, critic, states, actions, log_probs_old, values_old, advantages, epsilon=0.2, c1=0.5, c2=0.01):
    policy = actor(states)
    dist = torch.distributions.Categorical(policy)

    log_probs = dist.log_prob(actions)
    ratios = torch.exp(log_probs - log_probs_old)
    surr1 = ratios * advantages
    surr2 = torch.clamp(ratios, 1.0 - epsilon, 1.0 + epsilon) * advantages

    actor_loss = -torch.min(surr1, surr2).mean()

    values = critic(states)
    critic_loss = (values - values_old).pow(2).mean()

    entropy = dist.entropy().mean()

    total_loss = actor_loss + c1 * critic_loss - c2 * entropy

    return actor_loss, critic_loss

# Discounted rewards function
def discount_rewards(rewards, gamma=0.99):
    discounted_rewards = []
    running_add = 0
    for r in reversed(rewards):
        running_add = running_add * gamma + r
        discounted_rewards.insert(0, running_add)
    return discounted_rewards

# Function to compute advantages
def compute_advantages(critic, states, rewards):
    # print(f"Critic of compute advantages: {critic}")
    # print(f"states of compute advantages: {states}")
    # print(f"rewards of compute advantages: {rewards}")
    values = critic(states).squeeze()
    rewards_tensor = torch.tensor(rewards, dtype=torch.float32)  # Convert rewards to a PyTorch tensor
    # print(f"Length of rewards_tensor: {len(rewards)}")
    # print(f"Length of values_tensor: {len(values)}")
    advantages = rewards_tensor - values
    return advantages




class Case:
    added_states = set()  # Class attribute to store states already added to the case base

    def __init__(self, problem, solution, trust_value=1):
        self.problem = np.array(problem)  # Convert problem to numpy array
        self.solution = solution
        self.trust_value = trust_value
    
    @staticmethod
    def sim_q(state1, state2):
        state1 = np.atleast_1d(state1)  # Ensure state1 is at least 1-dimensional
        state2 = np.atleast_1d(state2)  # Ensure state2 is at least 1-dimensional
        CNDMaxDist = 6  # Maximum distance between two nodes in the CND
        v = state1.size  # Total number of objects the agent can perceive
        DistQ = np.sum([Case.Dmin_phi(Objic, Objip) for Objic, Objip in zip(state1, state2)])
        similarity = (CNDMaxDist * v - DistQ) / (CNDMaxDist * v)
        return similarity

    @staticmethod
    def Dmin_phi(X1, X2):
        return np.max(np.abs(X1 - X2))
    

    @staticmethod
    def retrieve(state, case_base, threshold=0.2):
        similarities = {}
        for case in case_base:
            similarities[case] = Case.sim_q(state, case.problem)  # Compare state with the problem part of the case
        
        sorted_similarities = sorted(similarities.items(), key=lambda x: x[1], reverse=True)
        
        if sorted_similarities:
            most_similar_case = sorted_similarities[0][0] if sorted_similarities[0][1] >= threshold else None
        else:
            most_similar_case = None
        
        return most_similar_case

    @staticmethod
    def reuse(c, temporary_case_base):
        temporary_case_base.append(c)
        # Store the new case from the problem solver
        # if c not in temporary_case_base:
            # temporary_case_base.append(c)
        
        # Check if there are similar cases in case_base
        # similar_cases = [case for case in case_base if np.array_equal(case.problem, c.problem)]
        # for similar_case in similar_cases:
            # temporary_case_base.append(similar_case)
            # if similar_case not in temporary_case_base:
            #     temporary_case_base.append(similar_case)

    @staticmethod
    def revise(case_base, temporary_case_base, successful_episodes):
        for case in temporary_case_base:
            if successful_episodes and case in case_base:
                case.trust_value += 0.1  # Increment trust value if the episode ended successfully and the case is in the case base
            elif not successful_episodes and case in case_base:
                case.trust_value -= 0.1  # Decrement trust value if the episode ended unsuccessfully and the case is in the case base
            case.trust_value = max(0, min(case.trust_value,1))  # Ensure trust value is within[0,1]

    @staticmethod
    def retain(case_base, temporary_case_base, successful_episodes, threshold=0):
        if successful_episodes:
            # Iterate through the temporary case base to find the last occurrence of each unique state
            for case in reversed(temporary_case_base):
                state = tuple(np.atleast_1d(case.problem))
                # Check if the state is already in the case base or has been added previously
                if state not in Case.added_states:
                    # Add the case to the case base if the state is new
                    case_base.append(case)
                    Case.added_states.add(state)
            
            # Filter case_base based on trust_value
            filtered_case_base = []
            for case in case_base:
                # print(f"trust value >= Threshold?: {case.trust_value} >= {threshold}?")
                if case.trust_value >= threshold:
                    # print(f"problem | trust value: {case.problem} | {case.trust_value}")
                    # print("case saved dong")
                    filtered_case_base.append(case)
                else:
                    # print(f"problem | trust value: {case.problem} | {case.trust_value}")
                    # print("case unsaved dong")
                    pass

            return filtered_case_base
        else:
            return case_base  # Return original case_base if episode is not successful

class QCBRL:
    def __init__(self, num_actions, env):
        self.num_actions = num_actions
        self.env = env
        self.problem_solver = ProblemSolver(env)
        self.case_base = []
        self.temporary_case_base = []

    def run(self, episodes, max_steps, alpha=0.1, gamma=0.9, epsilon=0.1, render=False):
        total_rewards = []
        # episode_rewards = []
        memory_usage = []
        gpu_memory_usage = []
        successful_episodes = False
        num_successful_episodes = 0
        total_steps_list = [] 

        pynvml.nvmlInit()
        handle = pynvml.nvmlDeviceGetHandleByIndex(0)

        for episode in range(episodes):
            state = self.env.reset()
            # print(f"State: {state}")
            self.temporary_case_base = []
            episode_reward = 0
            total_steps = 0
            
            states = []
            actions = []
            log_probs = []
            values = []
            rewards = []
            dones = []

            for _ in range(max_steps):
                # if render:
                #     env.render()
                action = self.take_action(state, epsilon)
                next_state, reward, done, _ = self.env.step(action)

                state_one_hot = torch.zeros(1, env.observation_space.n)
                state_one_hot[0, state] = 1
                states.append(state_one_hot)
                actions.append(action)
                rewards.append(reward)
                dones.append(done)

                c = Case(state, action)
                Case.reuse(c, self.temporary_case_base)

                policy = self.problem_solver.actor(state_one_hot)
                dist = torch.distributions.Categorical(policy)
                log_prob = dist.log_prob(torch.tensor(action))
                log_probs.append(log_prob)
                value = self.problem_solver.critic(state_one_hot)
                values.append(value)

                state = next_state
                episode_reward += reward
                total_steps += 1

                if done:
                    successful_episodes = reward > 0
                    break
                
                
                
            # print(f"States before policy: {states}")
            # print(f"Rewards before policy: {rewards}")
            self.problem_solver.update_policy(states, actions, log_probs, values, rewards, dones)
            
            # episode_rewards.append(sum(rewards))
            
            if episode_reward > 0:  # If the agent reached the goal state
                num_successful_episodes += 1
                total_steps_list.append(total_steps)  # Append total steps for this episode   
            else:
                total_steps_list.append(0)

            total_rewards.append(episode_reward)
            print(f"Episode {episode + 1}, Total Reward: {episode_reward}")

            Case.revise(self.case_base, self.temporary_case_base, successful_episodes)
            self.case_base = Case.retain(self.case_base, self.temporary_case_base, successful_episodes)
            
            memory_usage.append(psutil.virtual_memory().percent)
            gpu_memory_usage.append(pynvml.nvmlDeviceGetMemoryInfo(handle).used / 1024**2)

        
        self.save_case_base_temporary()  # Save temporary case base after training
        self.save_case_base()  # Save case base after training

        success_rate = (num_successful_episodes / episodes) * 100
        # print(f"Successful episodes: {num_successful_episodes}")

        # env.close()
        return total_rewards, success_rate, memory_usage, gpu_memory_usage, total_steps_list

    def take_action(self, state, epsilon):

        similar_solution = Case.retrieve(state, self.case_base)
        if similar_solution is not None:
            action = similar_solution.solution
            # print("action from case base")
        else:
            action = self.problem_solver.choose_action(state, epsilon)
            # print("action from problem solver")
        
        # action = self.problem_solver.choose_action(state, epsilon)
        
        return action
    
    def save_case_base_temporary(self):
        filename = "case_base_temporary.json"
        case_base_data = [{"problem": case.problem.tolist() if isinstance(case.problem, np.ndarray) else int(case.problem), 
                        "solution": int(case.solution), 
                        "trust_value": int(case.trust_value)} for case in self.temporary_case_base]
        with open(filename, 'w') as file:
            json.dump(case_base_data, file)
        print("Temporary case base saved successfully.")

    def save_case_base(self):
        filename = "case_base.json"
        case_base_data = [{"problem": case.problem.tolist() if isinstance(case.problem, np.ndarray) else int(case.problem), 
                        "solution": int(case.solution), 
                        "trust_value": int(case.trust_value)} for case in self.case_base]
        with open(filename, 'w') as file:
            json.dump(case_base_data, file)

            print("Case base saved successfully.")  # Add this line to check if the case base is being saved
        
    def load_case_base(self):
        filename = "case_base.json"
        try:
            with open(filename, 'r') as file:
                case_base_data = json.load(file)
                self.case_base = [Case(np.array(case["problem"]), case["solution"], case["trust_value"]) for case in case_base_data]
                print("Case base loaded successfully.")  # Add this line to check if the case base is being loaded
        except FileNotFoundError:
            print("Case base file not found. Starting with an empty case base.")

    
    def display_success_rate(self, success_rate):
        print(f"Success rate: {success_rate}%")


    def plot_rewards(self, rewards):
        plt.plot(rewards)
        plt.xlabel('Episode')
        plt.ylabel('Total Reward')
        plt.title('Rewards over Episodes')
        plt.grid(True)
        plt.show()

    def plot_resources(self, memory_usage, gpu_memory_usage):
        plt.plot(memory_usage, label='Memory (%)')
        plt.plot(gpu_memory_usage, label='GPU Memory (MB)')
        plt.xlabel('Episode')
        plt.ylabel('Resource Usage')
        plt.title('Resource Usage over Episodes')
        plt.legend()
        plt.grid(True)
        plt.show()
    
    def plot_total_steps(self, total_steps_list):
        plt.plot(total_steps_list)
        plt.xlabel('Episode')
        plt.ylabel('Total Steps')
        plt.title('Total Steps for Successful Episodes over Episodes')
        plt.grid(True)
        plt.show() 


class ProblemSolver:
    def __init__(self, env):
        self.env = env
        self.actor = Actor(env.observation_space.n, env.action_space.n)
        self.critic = Critic(env.observation_space.n)
        self.actor_optimizer = optim.Adam(self.actor.parameters(), lr=0.001)
        self.critic_optimizer = optim.Adam(self.critic.parameters(), lr=0.001)

    def choose_action(self, state, epsilon):
        state_one_hot = torch.zeros(1, self.env.observation_space.n)
        state_one_hot[0, state] = 1
        policy = self.actor(state_one_hot)
        action_probs = torch.softmax(policy, dim=-1)
        action = np.random.choice(env.action_space.n, p=action_probs.detach().numpy().flatten())
        return action

    def update_policy(self, states, actions, log_probs, values, rewards, dones):
        # print(f"Rewards before advantages: {rewards}")
        discounted_rewards = discount_rewards(rewards)
        # print(f"Discounted Rewards before advantages: {discounted_rewards}")
        # print(f"State before advantages: {states}")
        advantages = compute_advantages(self.critic, torch.stack(states), discounted_rewards)
        
        actions_tensor = torch.tensor(actions, dtype=torch.int64)
        log_probs_tensor = torch.cat(log_probs)
        values_tensor = torch.cat(values)
        advantages_tensor = torch.tensor(advantages, dtype=torch.float32)

        actor_loss, critic_loss = calculate_ppo_loss(self.actor, self.critic, torch.stack(states), actions_tensor, log_probs_tensor, values_tensor, advantages_tensor)

        self.actor_optimizer.zero_grad()
        self.critic_optimizer.zero_grad()
        actor_loss.backward()
        critic_loss.backward()
        self.actor_optimizer.step()
        self.critic_optimizer.step()



if __name__ == "__main__":
    env = CustomRewardFrozenLake()
    num_states = env.observation_space.n
    num_actions = env.action_space.n

    agent = QCBRL(num_actions, env)
    rewards, success_rate, memory_usage, gpu_memory_usage, total_step_list = agent.run(episodes=1000, max_steps=1000, alpha=0.1, gamma=0.9, epsilon=0.1)

    agent.display_success_rate(success_rate)
    agent.plot_rewards(rewards)
    agent.plot_resources(memory_usage, gpu_memory_usage)
    agent.plot_total_steps(total_step_list)
# Out:
# /tmp/ipykernel_19549/3701416978.py:426: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   advantages_tensor = torch.tensor(advantages, dtype=torch.float32)
# Episode 1, Total Reward: -5
# Episode 2, Total Reward: -5
# Episode 3, Total Reward: -5
# Episode 4, Total Reward: -5
# Episode 5, Total Reward: -5
# Episode 6, Total Reward: -5
# Episode 7, Total Reward: -5
# Episode 8, Total Reward: -5
# Episode 9, Total Reward: -5
# Episode 10, Total Reward: -5
# Episode 11, Total Reward: -5
# Episode 12, Total Reward: -5
# Episode 13, Total Reward: -5
# Episode 14, Total Reward: -5
# Episode 15, Total Reward: -5
# Episode 16, Total Reward: -5
# Episode 17, Total Reward: -5
# Episode 18, Total Reward: -5
# Episode 19, Total Reward: -5
# Episode 20, Total Reward: -5
# Episode 21, Total Reward: -5
# Episode 22, Total Reward: -5
# Episode 23, Total Reward: -5
# Episode 24, Total Reward: -5
# Episode 25, Total Reward: -5
# Episode 26, Total Reward: -5
# Episode 27, Total Reward: -5
# Episode 28, Total Reward: -5
# Episode 29, Total Reward: -5
# Episode 30, Total Reward: -5
# Episode 31, Total Reward: -5
# Episode 32, Total Reward: -5
# Episode 33, Total Reward: -5
# Episode 34, Total Reward: -5
# Episode 35, Total Reward: -5
# Episode 36, Total Reward: -5
# Episode 37, Total Reward: -5
# Episode 38, Total Reward: -5
# Episode 39, Total Reward: -5
# Episode 40, Total Reward: -5
# Episode 41, Total Reward: -5
# Episode 42, Total Reward: -5
# Episode 43, Total Reward: -5
# Episode 44, Total Reward: -5
# Episode 45, Total Reward: -5
# Episode 46, Total Reward: -5
# Episode 47, Total Reward: -5
# Episode 48, Total Reward: 1
# Episode 49, Total Reward: -5
# Episode 50, Total Reward: -5
# Episode 51, Total Reward: -5
# Episode 52, Total Reward: -5
# Episode 53, Total Reward: -5
# Episode 54, Total Reward: -5
# Episode 55, Total Reward: -5
# Episode 56, Total Reward: -5
# Episode 57, Total Reward: -5
# Episode 58, Total Reward: -5
# Episode 59, Total Reward: -5
# Episode 60, Total Reward: -5
# Episode 61, Total Reward: -5
# Episode 62, Total Reward: -5
# Episode 63, Total Reward: -5
# Episode 64, Total Reward: -5
# Episode 65, Total Reward: -5
# Episode 66, Total Reward: -5
# Episode 67, Total Reward: -5
# Episode 68, Total Reward: -5
# Episode 69, Total Reward: -5
# Episode 70, Total Reward: -5
# Episode 71, Total Reward: -5
# Episode 72, Total Reward: -5
# Episode 73, Total Reward: -5
# Episode 74, Total Reward: -5
# Episode 75, Total Reward: -5
# Episode 76, Total Reward: -5
# Episode 77, Total Reward: -5
# Episode 78, Total Reward: -5
# Episode 79, Total Reward: -5
# Episode 80, Total Reward: -5
# Episode 81, Total Reward: -5
# Episode 82, Total Reward: -5
# Episode 83, Total Reward: -5
# Episode 84, Total Reward: -5
# Episode 85, Total Reward: 1
# Episode 86, Total Reward: -5
# Episode 87, Total Reward: -5
# Episode 88, Total Reward: -5
# Episode 89, Total Reward: -5
# Episode 90, Total Reward: -5
# Episode 91, Total Reward: -5
# Episode 92, Total Reward: -5
# Episode 93, Total Reward: -5
# Episode 94, Total Reward: -5
# Episode 95, Total Reward: -5
# Episode 96, Total Reward: -5
# Episode 97, Total Reward: -5
# Episode 98, Total Reward: -5
# Episode 99, Total Reward: -5
# Episode 100, Total Reward: -5
# Episode 101, Total Reward: -5
# Episode 102, Total Reward: -5
# Episode 103, Total Reward: -5
# Episode 104, Total Reward: -5
# Episode 105, Total Reward: -5
# Episode 106, Total Reward: -5
# Episode 107, Total Reward: -5
# Episode 108, Total Reward: -5
# Episode 109, Total Reward: -5
# Episode 110, Total Reward: -5
# Episode 111, Total Reward: -5
# Episode 112, Total Reward: -5
# Episode 113, Total Reward: -5
# Episode 114, Total Reward: -5
# Episode 115, Total Reward: -5
# Episode 116, Total Reward: -5
# Episode 117, Total Reward: -5
# Episode 118, Total Reward: -5
# Episode 119, Total Reward: -5
# Episode 120, Total Reward: -5
# Episode 121, Total Reward: -5
# Episode 122, Total Reward: -5
# Episode 123, Total Reward: -5
# Episode 124, Total Reward: -5
# Episode 125, Total Reward: -5
# Episode 126, Total Reward: -5
# Episode 127, Total Reward: -5
# Episode 128, Total Reward: -5
# Episode 129, Total Reward: -5
# Episode 130, Total Reward: -5
# Episode 131, Total Reward: -5
# Episode 132, Total Reward: -5
# Episode 133, Total Reward: -5
# Episode 134, Total Reward: -5
# Episode 135, Total Reward: -5
# Episode 136, Total Reward: -5
# Episode 137, Total Reward: -5
# Episode 138, Total Reward: -5
# Episode 139, Total Reward: -5
# Episode 140, Total Reward: -5
# Episode 141, Total Reward: -5
# Episode 142, Total Reward: -5
# Episode 143, Total Reward: -5
# Episode 144, Total Reward: -5
# Episode 145, Total Reward: -5
# Episode 146, Total Reward: -5
# Episode 147, Total Reward: -5
# Episode 148, Total Reward: -5
# Episode 149, Total Reward: -5
# Episode 150, Total Reward: -5
# Episode 151, Total Reward: -5
# Episode 152, Total Reward: -5
# Episode 153, Total Reward: -5
# Episode 154, Total Reward: -5
# Episode 155, Total Reward: -5
# Episode 156, Total Reward: -5
# Episode 157, Total Reward: -5
# Episode 158, Total Reward: -5
# Episode 159, Total Reward: -5
# Episode 160, Total Reward: -5
# Episode 161, Total Reward: -5
# Episode 162, Total Reward: -5
# Episode 163, Total Reward: -5
# Episode 164, Total Reward: -5
# Episode 165, Total Reward: -5
# Episode 166, Total Reward: -5
# Episode 167, Total Reward: -5
# Episode 168, Total Reward: -5
# Episode 169, Total Reward: -5
# Episode 170, Total Reward: -5
# Episode 171, Total Reward: -5
# Episode 172, Total Reward: -5
# Episode 173, Total Reward: -5
# Episode 174, Total Reward: -5
# Episode 175, Total Reward: -5
# Episode 176, Total Reward: -5
# Episode 177, Total Reward: -5
# Episode 178, Total Reward: -5
# Episode 179, Total Reward: -5
# Episode 180, Total Reward: -5
# Episode 181, Total Reward: -5
# Episode 182, Total Reward: -5
# Episode 183, Total Reward: -5
# Episode 184, Total Reward: -5
# Episode 185, Total Reward: -5
# Episode 186, Total Reward: 1
# Episode 187, Total Reward: -5
# Episode 188, Total Reward: -5
# Episode 189, Total Reward: -5
# Episode 190, Total Reward: -5
# Episode 191, Total Reward: -5
# Episode 192, Total Reward: -5
# Episode 193, Total Reward: -5
# Episode 194, Total Reward: -5
# Episode 195, Total Reward: -5
# Episode 196, Total Reward: -5
# Episode 197, Total Reward: -5
# Episode 198, Total Reward: -5
# Episode 199, Total Reward: -5
# Episode 200, Total Reward: -5
# Episode 201, Total Reward: -5
# Episode 202, Total Reward: -5
# Episode 203, Total Reward: -5
# Episode 204, Total Reward: -5
# Episode 205, Total Reward: -5
# Episode 206, Total Reward: -5
# Episode 207, Total Reward: -5
# Episode 208, Total Reward: -5
# Episode 209, Total Reward: -5
# Episode 210, Total Reward: -5
# Episode 211, Total Reward: -5
# Episode 212, Total Reward: -5
# Episode 213, Total Reward: -5
# Episode 214, Total Reward: -5
# Episode 215, Total Reward: -5
# Episode 216, Total Reward: -5
# Episode 217, Total Reward: -5
# Episode 218, Total Reward: 1
# Episode 219, Total Reward: -5
# Episode 220, Total Reward: -5
# Episode 221, Total Reward: -5
# Episode 222, Total Reward: -5
# Episode 223, Total Reward: -5
# Episode 224, Total Reward: -5
# Episode 225, Total Reward: -5
# Episode 226, Total Reward: -5
# Episode 227, Total Reward: -5
# Episode 228, Total Reward: -5
# Episode 229, Total Reward: -5
# Episode 230, Total Reward: -5
# Episode 231, Total Reward: -5
# Episode 232, Total Reward: -5
# Episode 233, Total Reward: -5
# Episode 234, Total Reward: -5
# Episode 235, Total Reward: -5
# Episode 236, Total Reward: -5
# Episode 237, Total Reward: -5
# Episode 238, Total Reward: -5
# Episode 239, Total Reward: -5
# Episode 240, Total Reward: -5
# Episode 241, Total Reward: -5
# Episode 242, Total Reward: -5
# Episode 243, Total Reward: -5
# Episode 244, Total Reward: -5
# Episode 245, Total Reward: -5
# Episode 246, Total Reward: -5
# Episode 247, Total Reward: -5
# Episode 248, Total Reward: -5
# Episode 249, Total Reward: -5
# Episode 250, Total Reward: -5
# Episode 251, Total Reward: -5
# Episode 252, Total Reward: -5
# Episode 253, Total Reward: -5
# Episode 254, Total Reward: -5
# Episode 255, Total Reward: -5
# Episode 256, Total Reward: -5
# Episode 257, Total Reward: -5
# Episode 258, Total Reward: -5
# Episode 259, Total Reward: -5
# Episode 260, Total Reward: -5
# Episode 261, Total Reward: -5
# Episode 262, Total Reward: -5
# Episode 263, Total Reward: -5
# Episode 264, Total Reward: -5
# Episode 265, Total Reward: -5
# Episode 266, Total Reward: -5
# Episode 267, Total Reward: -5
# Episode 268, Total Reward: -5
# Episode 269, Total Reward: -5
# Episode 270, Total Reward: -5
# Episode 271, Total Reward: -5
# Episode 272, Total Reward: -5
# Episode 273, Total Reward: -5
# Episode 274, Total Reward: -5
# Episode 275, Total Reward: -5
# Episode 276, Total Reward: -5
# Episode 277, Total Reward: -5
# Episode 278, Total Reward: -5
# Episode 279, Total Reward: -5
# Episode 280, Total Reward: -5
# Episode 281, Total Reward: -5
# Episode 282, Total Reward: -5
# Episode 283, Total Reward: -5
# Episode 284, Total Reward: -5
# Episode 285, Total Reward: -5
# Episode 286, Total Reward: -5
# Episode 287, Total Reward: -5
# Episode 288, Total Reward: -5
# Episode 289, Total Reward: -5
# Episode 290, Total Reward: -5
# Episode 291, Total Reward: -5
# Episode 292, Total Reward: -5
# Episode 293, Total Reward: -5
# Episode 294, Total Reward: -5
# Episode 295, Total Reward: -5
# Episode 296, Total Reward: -5
# Episode 297, Total Reward: -5
# Episode 298, Total Reward: -5
# Episode 299, Total Reward: -5
# Episode 300, Total Reward: -5
# Episode 301, Total Reward: -5
# Episode 302, Total Reward: -5
# Episode 303, Total Reward: -5
# Episode 304, Total Reward: -5
# Episode 305, Total Reward: -5
# Episode 306, Total Reward: -5
# Episode 307, Total Reward: -5
# Episode 308, Total Reward: -5
# Episode 309, Total Reward: -5
# Episode 310, Total Reward: -5
# Episode 311, Total Reward: -5
# Episode 312, Total Reward: -5
# Episode 313, Total Reward: 1
# Episode 314, Total Reward: -5
# Episode 315, Total Reward: -5
# Episode 316, Total Reward: -5
# Episode 317, Total Reward: -5
# Episode 318, Total Reward: -5
# Episode 319, Total Reward: -5
# Episode 320, Total Reward: -5
# Episode 321, Total Reward: -5
# Episode 322, Total Reward: -5
# Episode 323, Total Reward: -5
# Episode 324, Total Reward: -5
# Episode 325, Total Reward: -5
# Episode 326, Total Reward: -5
# Episode 327, Total Reward: -5
# Episode 328, Total Reward: -5
# Episode 329, Total Reward: -5
# Episode 330, Total Reward: -5
# Episode 331, Total Reward: -5
# Episode 332, Total Reward: -5
# Episode 333, Total Reward: -5
# Episode 334, Total Reward: -5
# Episode 335, Total Reward: -5
# Episode 336, Total Reward: 1
# Episode 337, Total Reward: -5
# Episode 338, Total Reward: -5
# Episode 339, Total Reward: -5
# Episode 340, Total Reward: 1
# Episode 341, Total Reward: -5
# Episode 342, Total Reward: -5
# Episode 343, Total Reward: -5
# Episode 344, Total Reward: -5
# Episode 345, Total Reward: -5
# Episode 346, Total Reward: -5
# Episode 347, Total Reward: -5
# Episode 348, Total Reward: -5
# Episode 349, Total Reward: -5
# Episode 350, Total Reward: -5
# Episode 351, Total Reward: -5
# Episode 352, Total Reward: -5
# Episode 353, Total Reward: -5
# Episode 354, Total Reward: -5
# Episode 355, Total Reward: -5
# Episode 356, Total Reward: -5
# Episode 357, Total Reward: -5
# Episode 358, Total Reward: -5
# Episode 359, Total Reward: -5
# Episode 360, Total Reward: -5
# Episode 361, Total Reward: -5
# Episode 362, Total Reward: -5
# Episode 363, Total Reward: -5
# Episode 364, Total Reward: -5
# Episode 365, Total Reward: -5
# Episode 366, Total Reward: -5
# Episode 367, Total Reward: -5
# Episode 368, Total Reward: -5
# Episode 369, Total Reward: -5
# Episode 370, Total Reward: -5
# Episode 371, Total Reward: -5
# Episode 372, Total Reward: -5
# Episode 373, Total Reward: -5
# Episode 374, Total Reward: -5
# Episode 375, Total Reward: -5
# Episode 376, Total Reward: -5
# Episode 377, Total Reward: -5
# Episode 378, Total Reward: -5
# Episode 379, Total Reward: -5
# Episode 380, Total Reward: -5
# Episode 381, Total Reward: -5
# Episode 382, Total Reward: -5
# Episode 383, Total Reward: -5
# Episode 384, Total Reward: -5
# Episode 385, Total Reward: -5
# Episode 386, Total Reward: -5
# Episode 387, Total Reward: 1
# Episode 388, Total Reward: -5
# Episode 389, Total Reward: -5
# Episode 390, Total Reward: -5
# Episode 391, Total Reward: -5
# Episode 392, Total Reward: -5
# Episode 393, Total Reward: -5
# Episode 394, Total Reward: -5
# Episode 395, Total Reward: -5
# Episode 396, Total Reward: -5
# Episode 397, Total Reward: -5
# Episode 398, Total Reward: -5
# Episode 399, Total Reward: -5
# Episode 400, Total Reward: -5
# Episode 401, Total Reward: -5
# Episode 402, Total Reward: -5
# Episode 403, Total Reward: -5
# Episode 404, Total Reward: -5
# Episode 405, Total Reward: -5
# Episode 406, Total Reward: -5
# Episode 407, Total Reward: -5
# Episode 408, Total Reward: -5
# Episode 409, Total Reward: -5
# Episode 410, Total Reward: -5
# Episode 411, Total Reward: -5
# Episode 412, Total Reward: -5
# Episode 413, Total Reward: -5
# Episode 414, Total Reward: -5
# Episode 415, Total Reward: -5
# Episode 416, Total Reward: -5
# Episode 417, Total Reward: -5
# Episode 418, Total Reward: -5
# Episode 419, Total Reward: -5
# Episode 420, Total Reward: -5
# Episode 421, Total Reward: -5
# Episode 422, Total Reward: -5
# Episode 423, Total Reward: -5
# Episode 424, Total Reward: -5
# Episode 425, Total Reward: -5
# Episode 426, Total Reward: -5
# Episode 427, Total Reward: -5
# Episode 428, Total Reward: -5
# Episode 429, Total Reward: -5
# Episode 430, Total Reward: -5
# Episode 431, Total Reward: -5
# Episode 432, Total Reward: -5
# Episode 433, Total Reward: -5
# Episode 434, Total Reward: -5
# Episode 435, Total Reward: -5
# Episode 436, Total Reward: -5
# Episode 437, Total Reward: -5
# Episode 438, Total Reward: -5
# Episode 439, Total Reward: -5
# Episode 440, Total Reward: -5
# Episode 441, Total Reward: -5
# Episode 442, Total Reward: -5
# Episode 443, Total Reward: -5
# Episode 444, Total Reward: -5
# Episode 445, Total Reward: -5
# Episode 446, Total Reward: -5
# Episode 447, Total Reward: -5
# Episode 448, Total Reward: -5
# Episode 449, Total Reward: -5
# Episode 450, Total Reward: -5
# Episode 451, Total Reward: -5
# Episode 452, Total Reward: -5
# Episode 453, Total Reward: -5
# Episode 454, Total Reward: -5
# Episode 455, Total Reward: -5
# Episode 456, Total Reward: -5
# Episode 457, Total Reward: -5
# Episode 458, Total Reward: -5
# Episode 459, Total Reward: -5
# Episode 460, Total Reward: -5
# Episode 461, Total Reward: -5
# Episode 462, Total Reward: -5
# Episode 463, Total Reward: -5
# Episode 464, Total Reward: -5
# Episode 465, Total Reward: -5
# Episode 466, Total Reward: -5
# Episode 467, Total Reward: -5
# Episode 468, Total Reward: -5
# Episode 469, Total Reward: -5
# Episode 470, Total Reward: -5
# Episode 471, Total Reward: -5
# Episode 472, Total Reward: -5
# Episode 473, Total Reward: -5
# Episode 474, Total Reward: -5
# Episode 475, Total Reward: -5
# Episode 476, Total Reward: -5
# Episode 477, Total Reward: -5
# Episode 478, Total Reward: -5
# Episode 479, Total Reward: -5
# Episode 480, Total Reward: -5
# Episode 481, Total Reward: -5
# Episode 482, Total Reward: -5
# Episode 483, Total Reward: -5
# Episode 484, Total Reward: -5
# Episode 485, Total Reward: -5
# Episode 486, Total Reward: -5
# Episode 487, Total Reward: -5
# Episode 488, Total Reward: -5
# Episode 489, Total Reward: -5
# Episode 490, Total Reward: -5
# Episode 491, Total Reward: -5
# Episode 492, Total Reward: -5
# Episode 493, Total Reward: -5
# Episode 494, Total Reward: -5
# Episode 495, Total Reward: -5
# Episode 496, Total Reward: -5
# Episode 497, Total Reward: -5
# Episode 498, Total Reward: -5
# Episode 499, Total Reward: -5
# Episode 500, Total Reward: -5
# Episode 501, Total Reward: -5
# Episode 502, Total Reward: -5
# Episode 503, Total Reward: -5
# Episode 504, Total Reward: -5
# Episode 505, Total Reward: -5
# Episode 506, Total Reward: -5
# Episode 507, Total Reward: -5
# Episode 508, Total Reward: -5
# Episode 509, Total Reward: -5
# Episode 510, Total Reward: -5
# Episode 511, Total Reward: -5
# Episode 512, Total Reward: -5
# Episode 513, Total Reward: -5
# Episode 514, Total Reward: -5
# Episode 515, Total Reward: -5
# Episode 516, Total Reward: -5
# Episode 517, Total Reward: -5
# Episode 518, Total Reward: -5
# Episode 519, Total Reward: -5
# Episode 520, Total Reward: -5
# Episode 521, Total Reward: -5
# Episode 522, Total Reward: -5
# Episode 523, Total Reward: -5
# Episode 524, Total Reward: -5
# Episode 525, Total Reward: 1
# Episode 526, Total Reward: -5
# Episode 527, Total Reward: -5
# Episode 528, Total Reward: -5
# Episode 529, Total Reward: -5
# Episode 530, Total Reward: -5
# Episode 531, Total Reward: -5
# Episode 532, Total Reward: -5
# Episode 533, Total Reward: -5
# Episode 534, Total Reward: 1
# Episode 535, Total Reward: -5
# Episode 536, Total Reward: -5
# Episode 537, Total Reward: -5
# Episode 538, Total Reward: -5
# Episode 539, Total Reward: -5
# Episode 540, Total Reward: -5
# Episode 541, Total Reward: -5
# Episode 542, Total Reward: -5
# Episode 543, Total Reward: -5
# Episode 544, Total Reward: -5
# Episode 545, Total Reward: -5
# Episode 546, Total Reward: -5
# Episode 547, Total Reward: -5
# Episode 548, Total Reward: -5
# Episode 549, Total Reward: -5
# Episode 550, Total Reward: -5
# Episode 551, Total Reward: -5
# Episode 552, Total Reward: -5
# Episode 553, Total Reward: -5
# Episode 554, Total Reward: -5
# Episode 555, Total Reward: -5
# Episode 556, Total Reward: -5
# Episode 557, Total Reward: -5
# Episode 558, Total Reward: -5
# Episode 559, Total Reward: -5
# Episode 560, Total Reward: -5
# Episode 561, Total Reward: -5
# Episode 562, Total Reward: -5
# Episode 563, Total Reward: -5
# Episode 564, Total Reward: -5
# Episode 565, Total Reward: -5
# Episode 566, Total Reward: -5
# Episode 567, Total Reward: -5
# Episode 568, Total Reward: -5
# Episode 569, Total Reward: -5
# Episode 570, Total Reward: -5
# Episode 571, Total Reward: -5
# Episode 572, Total Reward: -5
# Episode 573, Total Reward: -5
# Episode 574, Total Reward: -5
# Episode 575, Total Reward: -5
# Episode 576, Total Reward: -5
# Episode 577, Total Reward: -5
# Episode 578, Total Reward: -5
# Episode 579, Total Reward: -5
# Episode 580, Total Reward: -5
# Episode 581, Total Reward: -5
# Episode 582, Total Reward: -5
# Episode 583, Total Reward: -5
# Episode 584, Total Reward: -5
# Episode 585, Total Reward: -5
# Episode 586, Total Reward: -5
# Episode 587, Total Reward: -5
# Episode 588, Total Reward: -5
# Episode 589, Total Reward: -5
# Episode 590, Total Reward: -5
# Episode 591, Total Reward: -5
# Episode 592, Total Reward: 1
# Episode 593, Total Reward: 1
# Episode 594, Total Reward: -5
# Episode 595, Total Reward: -5
# Episode 596, Total Reward: -5
# Episode 597, Total Reward: -5
# Episode 598, Total Reward: -5
# Episode 599, Total Reward: -5
# Episode 600, Total Reward: -5
# Episode 601, Total Reward: -5
# Episode 602, Total Reward: -5
# Episode 603, Total Reward: -5
# Episode 604, Total Reward: -5
# Episode 605, Total Reward: -5
# Episode 606, Total Reward: -5
# Episode 607, Total Reward: -5
# Episode 608, Total Reward: -5
# Episode 609, Total Reward: -5
# Episode 610, Total Reward: -5
# Episode 611, Total Reward: -5
# Episode 612, Total Reward: -5
# Episode 613, Total Reward: -5
# Episode 614, Total Reward: -5
# Episode 615, Total Reward: -5
# Episode 616, Total Reward: -5
# Episode 617, Total Reward: -5
# Episode 618, Total Reward: -5
# Episode 619, Total Reward: -5
# Episode 620, Total Reward: -5
# Episode 621, Total Reward: -5
# Episode 622, Total Reward: -5
# Episode 623, Total Reward: -5
# Episode 624, Total Reward: -5
# Episode 625, Total Reward: -5
# Episode 626, Total Reward: -5
# Episode 627, Total Reward: -5
# Episode 628, Total Reward: -5
# Episode 629, Total Reward: -5
# Episode 630, Total Reward: -5
# Episode 631, Total Reward: -5
# Episode 632, Total Reward: -5
# Episode 633, Total Reward: -5
# Episode 634, Total Reward: -5
# Episode 635, Total Reward: -5
# Episode 636, Total Reward: 1
# Episode 637, Total Reward: -5
# Episode 638, Total Reward: -5
# Episode 639, Total Reward: -5
# Episode 640, Total Reward: -5
# Episode 641, Total Reward: -5
# Episode 642, Total Reward: -5
# Episode 643, Total Reward: -5
# Episode 644, Total Reward: -5
# Episode 645, Total Reward: -5
# Episode 646, Total Reward: -5
# Episode 647, Total Reward: -5
# Episode 648, Total Reward: -5
# Episode 649, Total Reward: -5
# Episode 650, Total Reward: -5
# Episode 651, Total Reward: -5
# Episode 652, Total Reward: -5
# Episode 653, Total Reward: -5
# Episode 654, Total Reward: -5
# Episode 655, Total Reward: -5
# Episode 656, Total Reward: -5
# Episode 657, Total Reward: -5
# Episode 658, Total Reward: -5
# Episode 659, Total Reward: -5
# Episode 660, Total Reward: -5
# Episode 661, Total Reward: -5
# Episode 662, Total Reward: -5
# Episode 663, Total Reward: -5
# Episode 664, Total Reward: -5
# Episode 665, Total Reward: -5
# Episode 666, Total Reward: -5
# Episode 667, Total Reward: -5
# Episode 668, Total Reward: -5
# Episode 669, Total Reward: -5
# Episode 670, Total Reward: -5
# Episode 671, Total Reward: -5
# Episode 672, Total Reward: -5
# Episode 673, Total Reward: -5
# Episode 674, Total Reward: -5
# Episode 675, Total Reward: -5
# Episode 676, Total Reward: -5
# Episode 677, Total Reward: -5
# Episode 678, Total Reward: -5
# Episode 679, Total Reward: -5
# Episode 680, Total Reward: -5
# Episode 681, Total Reward: -5
# Episode 682, Total Reward: -5
# Episode 683, Total Reward: -5
# Episode 684, Total Reward: -5
# Episode 685, Total Reward: -5
# Episode 686, Total Reward: -5
# Episode 687, Total Reward: -5
# Episode 688, Total Reward: -5
# Episode 689, Total Reward: -5
# Episode 690, Total Reward: -5
# Episode 691, Total Reward: -5
# Episode 692, Total Reward: -5
# Episode 693, Total Reward: -5
# Episode 694, Total Reward: -5
# Episode 695, Total Reward: -5
# Episode 696, Total Reward: -5
# Episode 697, Total Reward: -5
# Episode 698, Total Reward: -5
# Episode 699, Total Reward: -5
# Episode 700, Total Reward: -5
# Episode 701, Total Reward: -5
# Episode 702, Total Reward: -5
# Episode 703, Total Reward: -5
# Episode 704, Total Reward: -5
# Episode 705, Total Reward: -5
# Episode 706, Total Reward: -5
# Episode 707, Total Reward: -5
# Episode 708, Total Reward: -5
# Episode 709, Total Reward: -5
# Episode 710, Total Reward: -5
# Episode 711, Total Reward: -5
# Episode 712, Total Reward: -5
# Episode 713, Total Reward: -5
# Episode 714, Total Reward: -5
# Episode 715, Total Reward: -5
# Episode 716, Total Reward: -5
# Episode 717, Total Reward: -5
# Episode 718, Total Reward: -5
# Episode 719, Total Reward: -5
# Episode 720, Total Reward: -5
# Episode 721, Total Reward: -5
# Episode 722, Total Reward: -5
# Episode 723, Total Reward: -5
# Episode 724, Total Reward: -5
# Episode 725, Total Reward: -5
# Episode 726, Total Reward: -5
# Episode 727, Total Reward: -5
# Episode 728, Total Reward: -5
# Episode 729, Total Reward: -5
# Episode 730, Total Reward: -5
# Episode 731, Total Reward: -5
# Episode 732, Total Reward: -5
# Episode 733, Total Reward: -5
# Episode 734, Total Reward: -5
# Episode 735, Total Reward: -5
# Episode 736, Total Reward: -5
# Episode 737, Total Reward: -5
# Episode 738, Total Reward: -5
# Episode 739, Total Reward: -5
# Episode 740, Total Reward: -5
# Episode 741, Total Reward: -5
# Episode 742, Total Reward: -5
# Episode 743, Total Reward: -5
# Episode 744, Total Reward: -5
# Episode 745, Total Reward: -5
# Episode 746, Total Reward: -5
# Episode 747, Total Reward: -5
# Episode 748, Total Reward: -5
# Episode 749, Total Reward: -5
# Episode 750, Total Reward: -5
# Episode 751, Total Reward: -5
# Episode 752, Total Reward: -5
# Episode 753, Total Reward: -5
# Episode 754, Total Reward: -5
# Episode 755, Total Reward: -5
# Episode 756, Total Reward: -5
# Episode 757, Total Reward: -5
# Episode 758, Total Reward: -5
# Episode 759, Total Reward: -5
# Episode 760, Total Reward: -5
# Episode 761, Total Reward: -5
# Episode 762, Total Reward: -5
# Episode 763, Total Reward: -5
# Episode 764, Total Reward: -5
# Episode 765, Total Reward: -5
# Episode 766, Total Reward: -5
# Episode 767, Total Reward: -5
# Episode 768, Total Reward: -5
# Episode 769, Total Reward: -5
# Episode 770, Total Reward: -5
# Episode 771, Total Reward: -5
# Episode 772, Total Reward: -5
# Episode 773, Total Reward: -5
# Episode 774, Total Reward: -5
# Episode 775, Total Reward: -5
# Episode 776, Total Reward: -5
# Episode 777, Total Reward: -5
# Episode 778, Total Reward: -5
# Episode 779, Total Reward: -5
# Episode 780, Total Reward: -5
# Episode 781, Total Reward: -5
# Episode 782, Total Reward: -5
# Episode 783, Total Reward: -5
# Episode 784, Total Reward: -5
# Episode 785, Total Reward: -5
# Episode 786, Total Reward: -5
# Episode 787, Total Reward: -5
# Episode 788, Total Reward: -5
# Episode 789, Total Reward: -5
# Episode 790, Total Reward: -5
# Episode 791, Total Reward: -5
# Episode 792, Total Reward: -5
# Episode 793, Total Reward: -5
# Episode 794, Total Reward: -5
# Episode 795, Total Reward: -5
# Episode 796, Total Reward: -5
# Episode 797, Total Reward: -5
# Episode 798, Total Reward: -5
# Episode 799, Total Reward: -5
# Episode 800, Total Reward: -5
# Episode 801, Total Reward: -5
# Episode 802, Total Reward: -5
# Episode 803, Total Reward: -5
# Episode 804, Total Reward: -5
# Episode 805, Total Reward: -5
# Episode 806, Total Reward: -5
# Episode 807, Total Reward: -5
# Episode 808, Total Reward: -5
# Episode 809, Total Reward: -5
# Episode 810, Total Reward: -5
# Episode 811, Total Reward: -5
# Episode 812, Total Reward: -5
# Episode 813, Total Reward: 1
# Episode 814, Total Reward: -5
# Episode 815, Total Reward: -5
# Episode 816, Total Reward: -5
# Episode 817, Total Reward: -5
# Episode 818, Total Reward: -5
# Episode 819, Total Reward: -5
# Episode 820, Total Reward: -5
# Episode 821, Total Reward: -5
# Episode 822, Total Reward: -5
# Episode 823, Total Reward: 1
# Episode 824, Total Reward: -5
# Episode 825, Total Reward: -5
# Episode 826, Total Reward: -5
# Episode 827, Total Reward: -5
# Episode 828, Total Reward: -5
# Episode 829, Total Reward: -5
# Episode 830, Total Reward: -5
# Episode 831, Total Reward: -5
# Episode 832, Total Reward: -5
# Episode 833, Total Reward: -5
# Episode 834, Total Reward: -5
# Episode 835, Total Reward: -5
# Episode 836, Total Reward: -5
# Episode 837, Total Reward: -5
# Episode 838, Total Reward: -5
# Episode 839, Total Reward: -5
# Episode 840, Total Reward: -5
# Episode 841, Total Reward: -5
# Episode 842, Total Reward: -5
# Episode 843, Total Reward: -5
# Episode 844, Total Reward: -5
# Episode 845, Total Reward: -5
# Episode 846, Total Reward: -5
# Episode 847, Total Reward: -5
# Episode 848, Total Reward: -5
# Episode 849, Total Reward: -5
# Episode 850, Total Reward: -5
# Episode 851, Total Reward: -5
# Episode 852, Total Reward: -5
# Episode 853, Total Reward: -5
# Episode 854, Total Reward: -5
# Episode 855, Total Reward: -5
# Episode 856, Total Reward: -5
# Episode 857, Total Reward: -5
# Episode 858, Total Reward: -5
# Episode 859, Total Reward: -5
# Episode 860, Total Reward: -5
# Episode 861, Total Reward: 1
# Episode 862, Total Reward: -5
# Episode 863, Total Reward: -5
# Episode 864, Total Reward: -5
# Episode 865, Total Reward: -5
# Episode 866, Total Reward: -5
# Episode 867, Total Reward: -5
# Episode 868, Total Reward: -5
# Episode 869, Total Reward: -5
# Episode 870, Total Reward: -5
# Episode 871, Total Reward: -5
# Episode 872, Total Reward: -5
# Episode 873, Total Reward: -5
# Episode 874, Total Reward: -5
# Episode 875, Total Reward: -5
# Episode 876, Total Reward: -5
# Episode 877, Total Reward: -5
# Episode 878, Total Reward: -5
# Episode 879, Total Reward: -5
# Episode 880, Total Reward: -5
# Episode 881, Total Reward: -5
# Episode 882, Total Reward: -5
# Episode 883, Total Reward: -5
# Episode 884, Total Reward: -5
# Episode 885, Total Reward: -5
# Episode 886, Total Reward: -5
# Episode 887, Total Reward: -5
# Episode 888, Total Reward: -5
# Episode 889, Total Reward: -5
# Episode 890, Total Reward: -5
# Episode 891, Total Reward: -5
# Episode 892, Total Reward: -5
# Episode 893, Total Reward: -5
# Episode 894, Total Reward: -5
# Episode 895, Total Reward: 1
# Episode 896, Total Reward: -5
# Episode 897, Total Reward: -5
# Episode 898, Total Reward: -5
# Episode 899, Total Reward: -5
# Episode 900, Total Reward: -5
# Episode 901, Total Reward: -5
# Episode 902, Total Reward: -5
# Episode 903, Total Reward: -5
# Episode 904, Total Reward: -5
# Episode 905, Total Reward: -5
# Episode 906, Total Reward: -5
# Episode 907, Total Reward: -5
# Episode 908, Total Reward: -5
# Episode 909, Total Reward: -5
# Episode 910, Total Reward: -5
# Episode 911, Total Reward: -5
# Episode 912, Total Reward: -5
# Episode 913, Total Reward: -5
# Episode 914, Total Reward: -5
# Episode 915, Total Reward: -5
# Episode 916, Total Reward: -5
# Episode 917, Total Reward: -5
# Episode 918, Total Reward: -5
# Episode 919, Total Reward: -5
# Episode 920, Total Reward: -5
# Episode 921, Total Reward: -5
# Episode 922, Total Reward: -5
# Episode 923, Total Reward: -5
# Episode 924, Total Reward: -5
# Episode 925, Total Reward: -5
# Episode 926, Total Reward: -5
# Episode 927, Total Reward: -5
# Episode 928, Total Reward: -5
# Episode 929, Total Reward: -5
# Episode 930, Total Reward: -5
# Episode 931, Total Reward: -5
# Episode 932, Total Reward: -5
# Episode 933, Total Reward: -5
# Episode 934, Total Reward: -5
# Episode 935, Total Reward: -5
# Episode 936, Total Reward: -5
# Episode 937, Total Reward: -5
# Episode 938, Total Reward: -5
# Episode 939, Total Reward: -5
# Episode 940, Total Reward: -5
# Episode 941, Total Reward: -5
# Episode 942, Total Reward: -5
# Episode 943, Total Reward: -5
# Episode 944, Total Reward: -5
# Episode 945, Total Reward: -5
# Episode 946, Total Reward: -5
# Episode 947, Total Reward: -5
# Episode 948, Total Reward: -5
# Episode 949, Total Reward: -5
# Episode 950, Total Reward: -5
# Episode 951, Total Reward: -5
# Episode 952, Total Reward: -5
# Episode 953, Total Reward: -5
# Episode 954, Total Reward: -5
# Episode 955, Total Reward: -5
# Episode 956, Total Reward: -5
# Episode 957, Total Reward: -5
# Episode 958, Total Reward: -5
# Episode 959, Total Reward: -5
# Episode 960, Total Reward: -5
# Episode 961, Total Reward: -5
# Episode 962, Total Reward: -5
# Episode 963, Total Reward: -5
# Episode 964, Total Reward: -5
# Episode 965, Total Reward: -5
# Episode 966, Total Reward: -5
# Episode 967, Total Reward: -5
# Episode 968, Total Reward: -5
# Episode 969, Total Reward: -5
# Episode 970, Total Reward: -5
# Episode 971, Total Reward: -5
# Episode 972, Total Reward: -5
# Episode 973, Total Reward: -5
# Episode 974, Total Reward: -5
# Episode 975, Total Reward: -5
# Episode 976, Total Reward: -5
# Episode 977, Total Reward: -5
# Episode 978, Total Reward: -5
# Episode 979, Total Reward: -5
# Episode 980, Total Reward: -5
# Episode 981, Total Reward: -5
# Episode 982, Total Reward: -5
# Episode 983, Total Reward: -5
# Episode 984, Total Reward: -5
# Episode 985, Total Reward: -5
# Episode 986, Total Reward: -5
# Episode 987, Total Reward: -5
# Episode 988, Total Reward: -5
# Episode 989, Total Reward: -5
# Episode 990, Total Reward: -5
# Episode 991, Total Reward: -5
# Episode 992, Total Reward: -5
# Episode 993, Total Reward: -5
# Episode 994, Total Reward: -5
# Episode 995, Total Reward: -5
# Episode 996, Total Reward: -5
# Episode 997, Total Reward: -5
# Episode 998, Total Reward: -5
# Episode 999, Total Reward: -5
# Episode 1000, Total Reward: -5
# Temporary case base saved successfully.
# Case base saved successfully.
# Success rate: 1.7000000000000002%
