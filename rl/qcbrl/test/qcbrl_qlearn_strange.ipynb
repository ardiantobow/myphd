# %%
import numpy as np
import json
import gym
import matplotlib.pyplot as plt
import psutil
import pynvml
from collections import Counter

class ProblemSolver:
    def __init__(self, actions, epsilon=0.1, gamma=0.99, alpha=0.1, lambd=0.9):
        self.actions = actions
        self.epsilon = epsilon
        self.gamma = gamma
        self.alpha = alpha
        self.lambd = lambd
        self.Q = {}  # Q-values table
        self.e = {}  # Eligibility traces table

    def choose_action(self, state):
        if np.isscalar(state):  # Check if state is a scalar (integer or float)
            state_array = np.array([state])  # Convert scalar to numpy array
        else:
            state_array = np.asarray(state)  # Ensure state is a numpy array

        state_tuple = (state_array.item(),) if state_array.ndim == 0 else tuple(state_array.tolist())

        if np.random.rand() < self.epsilon:
            return np.random.choice(self.actions)
        else:
            if state_tuple in self.Q:  # Use the tuple as the key
                return np.argmax(self.Q[state_tuple])
            else:
                return np.random.choice(self.actions)

    def update_Q(self, state, action, reward, next_state, next_action):
        state_array = np.asarray(state)  # Ensure state is a numpy array
        state_tuple = tuple(state_array.tolist())  # Convert numpy array to tuple

        if state_tuple not in self.Q:
            self.Q[state_tuple] = np.zeros(self.actions)
            self.e[state_tuple] = np.zeros(self.actions)

        delta = reward + self.gamma * self.Q.get(tuple(np.array(next_state).tolist()), np.zeros(self.actions))[next_action] - self.Q[state_tuple][action]
        self.e[state_tuple][action] += 1

        for s in self.Q:
            for a in range(self.actions):
                self.Q[s][a] += self.alpha * delta * self.e[s][a]
                self.e[s][a] *= self.gamma * self.lambd

class Case:
    added_states = set()  # Class attribute to store states already added to the case base

    def __init__(self, problem, solution, trust_value=1):
        self.problem = np.array(problem)  # Convert problem to numpy array
        self.solution = solution
        self.trust_value = trust_value

    @staticmethod
    def retrieve(state, case_base, threshold=0.5):
        similarities = {}
        for case in case_base:
            similarities[case] = Case.sim_q(state, case.problem)  # Compare state with the problem part of the case
        
        sorted_similarities = sorted(similarities.items(), key=lambda x: x[1], reverse=True)
        
        if sorted_similarities:
            most_similar_case = sorted_similarities[0][0] if sorted_similarities[0][1] >= threshold else None
        else:
            most_similar_case = None
        
        return most_similar_case

    @staticmethod
    def reuse(c, case_base, temporary_case_base):
        # Store the new case from the problem solver
        if c not in temporary_case_base:
            temporary_case_base.append(c)
        
        # Check if there are similar cases in case_base
        similar_cases = [case for case in case_base if np.array_equal(case.problem, c.problem)]
        for similar_case in similar_cases:
            if similar_case not in temporary_case_base:
                temporary_case_base.append(similar_case)

    @staticmethod
    def revise(case_base, temporary_case_base, episode_ended_successfully):
        for case in temporary_case_base:
            if episode_ended_successfully and case in case_base:
                case.trust_value += 0.1  # Increment trust value if the episode ended successfully and the case is in the case base
            elif not episode_ended_successfully and case in case_base:
                case.trust_value -= 0.1  # Decrement trust value if the episode ended unsuccessfully and the case is in the case base
            case.trust_value = max(0, min(case.trust_value,1))  # Ensure trust value is within[0,1]

    @staticmethod
    def retain(case_base, temporary_case_base, episode_ended_successfully, threshold=0.5):
        if episode_ended_successfully:
            # Iterate through the temporary case base to find the last occurrence of each unique state
            for case in reversed(temporary_case_base):
                state = tuple(np.atleast_1d(case.problem))
                # Check if the state is already in the case base or has been added previously
                if state not in Case.added_states:
                    # Add the case to the case base if the state is new
                    case_base.append(case)
                    Case.added_states.add(state)
            
            # Remove cases with trust value < threshold
            # for case in case_base:
            #     print(f"trust value: {case.trust_value}")
            #     print(f"threshold: {threshold}")
            #     if case.trust_value > threshold:
            #         print("gedhe")

            filtered_case_base = []
            for case in case_base:
                print(f"trust value >= Threshold?: {case.trust_value} >= {threshold}?")
                if case.trust_value >= threshold:
                    print(f"problem | trust value: {case.problem} | {case.trust_value}")
                    print("case saved dong")
                    filtered_case_base.append(case)
                else:
                    print(f"problem | trust value: {case.problem} | {case.trust_value}")
                    print("case unsaved dong")

            # case_base = filtered_case_base
            
    @staticmethod
    def sim_q(state1, state2):
        state1 = np.atleast_1d(state1)  # Ensure state1 is at least 1-dimensional
        state2 = np.atleast_1d(state2)  # Ensure state2 is at least 1-dimensional
        CNDMaxDist = 6  # Maximum distance between two nodes in the CND
        v = state1.size  # Total number of objects the agent can perceive
        DistQ = np.sum([Case.Dmin_phi(Objic, Objip) for Objic, Objip in zip(state1, state2)])
        similarity = (CNDMaxDist * v - DistQ) / (CNDMaxDist * v)
        return similarity

    @staticmethod
    def Dmin_phi(X1, X2):
        return np.max(np.abs(X1 - X2))

class QCBRL:
    def __init__(self, actions, threshold=0.5, epsilon=0.1, gamma=0.99, alpha=0.1, lambd=0.9):
        self.problem_solver = ProblemSolver(actions, epsilon, gamma, alpha, lambd)
        self.case_base = []
        self.threshold = threshold
        self.temporary_case_base = []
        # self.load_case_base()  # Load case base at initialization

    def train(self, episodes, max_steps, render=False):
        env = gym.make('FrozenLake-v1')
        rewards = []
        episode_rewards = []
        memory_usage = []
        gpu_memory_usage = []
        successful_episodes = 0  # Initialize counter for successful episodes

        pynvml.nvmlInit()
        handle = pynvml.nvmlDeviceGetHandleByIndex(0)  # GPU Index

        for episode in range(1, episodes + 1):
            state = env.reset()
            total_reward = 0
            self.temporary_case_base = []

            for step in range(max_steps):
                if render:
                    env.render()
                action, next_state = self.take_action(state)
                next_state, reward, done, _ = env.step(action)
                next_state = np.array(next_state)
                total_reward += reward

                state = next_state
                
                if done:
                    rewards.append(total_reward)
                    episode_rewards.append(total_reward)
                    if reward == 1.0:
                        episode_ended_successfully = True
                        successful_episodes += 1  # Increment successful episode counter
                    else:
                        episode_ended_successfully = False

                    print(f"Episode {episode} ended after {step + 1} steps with total reward: {total_reward}")
                    break

            Case.revise(self.case_base, self.temporary_case_base, episode_ended_successfully)
            Case.retain(self.case_base, self.temporary_case_base, episode_ended_successfully, self.threshold)
            # Save case base after each episode
            # self.save_case_base(self.case_base)

            memory_usage.append(psutil.virtual_memory().percent)
            gpu_memory_usage.append(pynvml.nvmlDeviceGetMemoryInfo(handle).used / 1024**2)

        self.save_case_base_temporary()  # Save temporary case base after training
        self.save_case_base()  # Save case base after training

        env.close()
        self.plot_rewards(episode_rewards)
        self.plot_resources(memory_usage, gpu_memory_usage)
        
        # Calculate and display percentage of successful episodes
        success_percentage = (successful_episodes / episodes) * 100
        print(f"Percentage of Successful Episodes: {success_percentage}%")


    def take_action(self, state):
        if np.isscalar(state):
            state_array = np.array([state])
        else:
            state_array = np.asarray(state)

        similar_solution = Case.retrieve(state_array, self.case_base)
        if similar_solution is not None:
            action = similar_solution.solution
            next_state = state
        else:
            action = self.problem_solver.choose_action(state_array)
            next_state = state_array

        if not isinstance(next_state, np.ndarray):
            next_state = np.array(next_state)

        # Add new case and similar cases to temporary_case_base
        c = Case(state, action)
        Case.reuse(c, self.case_base, self.temporary_case_base)

        return action, next_state

    def save_case_base_temporary(self):
        filename = "case_base_temporary.json"
        case_base_data = [{"problem": case.problem.tolist(), "solution": case.solution, "trust_value": case.trust_value} for case in self.temporary_case_base]
        with open(filename, 'w') as file:
            json.dump(case_base_data, file)

    def save_case_base(self):
        filename = "case_base.json"
        case_base_data = [{"problem": case.problem.tolist(), "solution": case.solution, "trust_value": case.trust_value} for case in self.case_base]
        with open(filename, 'w') as file:
            json.dump(case_base_data, file)

            print("Case base saved successfully.")  # Add this line to check if the case base is being saved
        
    def load_case_base(self):
        filename = "case_base.json"
        try:
            with open(filename, 'r') as file:
                case_base_data = json.load(file)
                self.case_base = [Case(np.array(case["problem"]), case["solution"], case["trust_value"]) for case in case_base_data]
                print("Case base loaded successfully.")  # Add this line to check if the case base is being loaded
        except FileNotFoundError:
            print("Case base file not found. Starting with an empty case base.")

    def plot_rewards(self, rewards):
        plt.plot(rewards)
        plt.xlabel('Episode')
        plt.ylabel('Total Reward')
        plt.title('Rewards over Episodes')
        plt.grid(True)
        plt.show() 

    def plot_resources(self, memory_usage, gpu_memory_usage):
        plt.plot(memory_usage, label='Memory (%)')
        plt.plot(gpu_memory_usage, label='GPU Memory (MB)')
        plt.xlabel('Episode')
        plt.ylabel('Resource Usage')
        plt.title('Resource Usage over Episodes')
        plt.legend()
        plt.grid(True)
        plt.show()

if __name__ == "__main__":
    actions = 4  # Number of actions in FrozenLake-v1
    agent = QCBRL(actions)
    agent.train(episodes=10000, max_steps=100000)
# Out:
# /home/ardie85/PHD/Research/code/.venv/lib/python3.10/site-packages/gym/wrappers/monitoring/video_recorder.py:9: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils.spawn
# Episode 1 ended after 6 steps with total reward: 0.0
# Episode 2 ended after 11 steps with total reward: 0.0
# Episode 3 ended after 7 steps with total reward: 0.0
# Episode 4 ended after 9 steps with total reward: 0.0
# Episode 5 ended after 11 steps with total reward: 0.0
# Episode 6 ended after 7 steps with total reward: 0.0
# Episode 7 ended after 13 steps with total reward: 0.0
# Episode 8 ended after 8 steps with total reward: 0.0
# Episode 9 ended after 21 steps with total reward: 0.0
# Episode 10 ended after 13 steps with total reward: 0.0
# Episode 11 ended after 12 steps with total reward: 0.0
# Episode 12 ended after 10 steps with total reward: 0.0
# Episode 13 ended after 9 steps with total reward: 0.0
# Episode 14 ended after 7 steps with total reward: 0.0
# Episode 15 ended after 7 steps with total reward: 0.0
# Episode 16 ended after 16 steps with total reward: 0.0
# Episode 17 ended after 9 steps with total reward: 0.0
# Episode 18 ended after 3 steps with total reward: 0.0
# Episode 19 ended after 5 steps with total reward: 0.0
# Episode 20 ended after 6 steps with total reward: 0.0
# Episode 21 ended after 3 steps with total reward: 0.0
# Episode 22 ended after 8 steps with total reward: 0.0
# Episode 23 ended after 10 steps with total reward: 0.0
# Episode 24 ended after 41 steps with total reward: 0.0
# Episode 25 ended after 6 steps with total reward: 0.0
# Episode 26 ended after 12 steps with total reward: 0.0
# Episode 27 ended after 3 steps with total reward: 0.0
# Episode 28 ended after 4 steps with total reward: 0.0
# Episode 29 ended after 5 steps with total reward: 0.0
# Episode 30 ended after 5 steps with total reward: 0.0
# Episode 31 ended after 6 steps with total reward: 0.0
# Episode 32 ended after 11 steps with total reward: 0.0
# Episode 33 ended after 18 steps with total reward: 0.0
# Episode 34 ended after 2 steps with total reward: 0.0
# Episode 35 ended after 8 steps with total reward: 0.0
# Episode 36 ended after 6 steps with total reward: 0.0
# Episode 37 ended after 5 steps with total reward: 0.0
# Episode 38 ended after 11 steps with total reward: 0.0
# Episode 39 ended after 4 steps with total reward: 0.0
# Episode 40 ended after 6 steps with total reward: 0.0
# Episode 41 ended after 6 steps with total reward: 0.0
# Episode 42 ended after 9 steps with total reward: 0.0
# Episode 43 ended after 4 steps with total reward: 0.0
# Episode 44 ended after 4 steps with total reward: 0.0
# Episode 45 ended after 18 steps with total reward: 0.0
# Episode 46 ended after 9 steps with total reward: 0.0
# Episode 47 ended after 10 steps with total reward: 1.0
# Episode 48 ended after 8 steps with total reward: 0.0
# Episode 49 ended after 3 steps with total reward: 0.0
# Episode 50 ended after 10 steps with total reward: 0.0
# Episode 51 ended after 27 steps with total reward: 1.0
# Episode 52 ended after 7 steps with total reward: 0.0
# Episode 53 ended after 20 steps with total reward: 0.0
# Episode 54 ended after 14 steps with total reward: 0.0
# Episode 55 ended after 8 steps with total reward: 0.0
# Episode 56 ended after 35 steps with total reward: 1.0
# Episode 57 ended after 7 steps with total reward: 0.0
# Episode 58 ended after 12 steps with total reward: 0.0
# Episode 59 ended after 15 steps with total reward: 0.0
# Episode 60 ended after 20 steps with total reward: 0.0
# Episode 61 ended after 2 steps with total reward: 0.0
# Episode 62 ended after 8 steps with total reward: 0.0
# Episode 63 ended after 11 steps with total reward: 0.0
# Episode 64 ended after 4 steps with total reward: 0.0
# Episode 65 ended after 13 steps with total reward: 0.0
# Episode 66 ended after 6 steps with total reward: 0.0
# Episode 67 ended after 3 steps with total reward: 0.0
# Episode 68 ended after 9 steps with total reward: 0.0
# Episode 69 ended after 2 steps with total reward: 0.0
# Episode 70 ended after 3 steps with total reward: 0.0
# Episode 71 ended after 10 steps with total reward: 0.0
# Episode 72 ended after 4 steps with total reward: 0.0
# Episode 73 ended after 2 steps with total reward: 0.0
# Episode 74 ended after 4 steps with total reward: 0.0
# Episode 75 ended after 14 steps with total reward: 0.0
# Episode 76 ended after 7 steps with total reward: 0.0
# Episode 77 ended after 4 steps with total reward: 0.0
# Episode 78 ended after 7 steps with total reward: 0.0
# Episode 79 ended after 2 steps with total reward: 0.0
# Episode 80 ended after 6 steps with total reward: 0.0
# Episode 81 ended after 5 steps with total reward: 0.0
# Episode 82 ended after 2 steps with total reward: 0.0
# Episode 83 ended after 4 steps with total reward: 0.0
# Episode 84 ended after 3 steps with total reward: 0.0
# Episode 85 ended after 2 steps with total reward: 0.0
# Episode 86 ended after 2 steps with total reward: 0.0
# Episode 149 ended after 38 steps with total reward: 0.0
# Episode 150 ended after 7 steps with total reward: 0.0
# Episode 151 ended after 15 steps with total reward: 0.0
# Episode 152 ended after 10 steps with total reward: 0.0
# Episode 153 ended after 7 steps with total reward: 1.0
# Episode 154 ended after 22 steps with total reward: 0.0
# Episode 155 ended after 21 steps with total reward: 0.0
# Episode 156 ended after 4 steps with total reward: 0.0
# Episode 157 ended after 14 steps with total reward: 0.0
# Episode 158 ended after 3 steps with total reward: 0.0
# Episode 159 ended after 7 steps with total reward: 0.0
# Episode 160 ended after 18 steps with total reward: 1.0
# Episode 161 ended after 12 steps with total reward: 0.0
# Episode 162 ended after 7 steps with total reward: 0.0
# Episode 163 ended after 18 steps with total reward: 0.0
# Episode 164 ended after 7 steps with total reward: 0.0
# Episode 165 ended after 6 steps with total reward: 0.0
# Episode 166 ended after 13 steps with total reward: 0.0
# Episode 167 ended after 14 steps with total reward: 0.0
# Episode 168 ended after 15 steps with total reward: 0.0
# Episode 169 ended after 5 steps with total reward: 0.0
# Episode 170 ended after 19 steps with total reward: 0.0
# Episode 171 ended after 51 steps with total reward: 0.0
# Episode 172 ended after 6 steps with total reward: 0.0
# Episode 173 ended after 27 steps with total reward: 0.0
# Episode 174 ended after 11 steps with total reward: 0.0
# Episode 175 ended after 15 steps with total reward: 0.0
# Episode 176 ended after 5 steps with total reward: 0.0
# Episode 177 ended after 6 steps with total reward: 0.0
# Episode 178 ended after 7 steps with total reward: 0.0
# Episode 179 ended after 23 steps with total reward: 0.0
# Episode 180 ended after 23 steps with total reward: 0.0
# Episode 181 ended after 16 steps with total reward: 0.0
# Episode 182 ended after 9 steps with total reward: 0.0
# Episode 183 ended after 4 steps with total reward: 0.0
# Episode 184 ended after 5 steps with total reward: 0.0
# Episode 185 ended after 14 steps with total reward: 0.0
# Episode 186 ended after 5 steps with total reward: 0.0
# Episode 187 ended after 11 steps with total reward: 0.0
# Episode 188 ended after 10 steps with total reward: 0.0
# Episode 189 ended after 6 steps with total reward: 0.0
# Episode 190 ended after 11 steps with total reward: 0.0
# Episode 191 ended after 20 steps with total reward: 0.0
# Episode 192 ended after 14 steps with total reward: 0.0
# Episode 193 ended after 7 steps with total reward: 0.0
# Episode 194 ended after 16 steps with total reward: 0.0
# Episode 195 ended after 15 steps with total reward: 0.0
# Episode 196 ended after 74 steps with total reward: 1.0
# Episode 197 ended after 12 steps with total reward: 0.0
# Episode 198 ended after 18 steps with total reward: 0.0
# Episode 199 ended after 7 steps with total reward: 0.0
# Episode 200 ended after 26 steps with total reward: 0.0
# Episode 201 ended after 46 steps with total reward: 0.0
# Episode 202 ended after 15 steps with total reward: 0.0
# Episode 203 ended after 10 steps with total reward: 0.0
# Episode 204 ended after 13 steps with total reward: 0.0
# Episode 205 ended after 4 steps with total reward: 0.0
# Episode 206 ended after 9 steps with total reward: 0.0
# Episode 207 ended after 22 steps with total reward: 0.0
# Episode 208 ended after 12 steps with total reward: 0.0
# Episode 209 ended after 9 steps with total reward: 0.0
# Episode 210 ended after 11 steps with total reward: 0.0
# Episode 211 ended after 43 steps with total reward: 0.0
# Episode 212 ended after 11 steps with total reward: 0.0
# Episode 213 ended after 10 steps with total reward: 0.0
# Episode 214 ended after 13 steps with total reward: 0.0
# Episode 215 ended after 6 steps with total reward: 0.0
# Episode 216 ended after 25 steps with total reward: 0.0
# Episode 217 ended after 7 steps with total reward: 0.0
# Episode 218 ended after 6 steps with total reward: 0.0
# Episode 219 ended after 4 steps with total reward: 0.0
# Episode 220 ended after 20 steps with total reward: 0.0
# Episode 221 ended after 14 steps with total reward: 0.0
# Episode 222 ended after 18 steps with total reward: 0.0
# Episode 223 ended after 13 steps with total reward: 0.0
# Episode 224 ended after 20 steps with total reward: 0.0
# Episode 225 ended after 4 steps with total reward: 0.0
# Episode 226 ended after 10 steps with total reward: 0.0
# Episode 227 ended after 8 steps with total reward: 0.0
# Episode 228 ended after 8 steps with total reward: 1.0
# Episode 229 ended after 25 steps with total reward: 0.0
# Episode 230 ended after 10 steps with total reward: 0.0
# Episode 231 ended after 7 steps with total reward: 0.0
# Episode 232 ended after 12 steps with total reward: 0.0
# Episode 233 ended after 4 steps with total reward: 0.0
# Episode 234 ended after 16 steps with total reward: 0.0
# Episode 235 ended after 25 steps with total reward: 0.0
# Episode 236 ended after 12 steps with total reward: 0.0
# Episode 237 ended after 27 steps with total reward: 0.0
# Episode 238 ended after 30 steps with total reward: 0.0
# Episode 239 ended after 17 steps with total reward: 0.0
# Episode 240 ended after 29 steps with total reward: 0.0
# Episode 241 ended after 5 steps with total reward: 0.0
# Episode 242 ended after 15 steps with total reward: 0.0
# Episode 243 ended after 8 steps with total reward: 0.0
# Episode 244 ended after 5 steps with total reward: 0.0
# Episode 245 ended after 11 steps with total reward: 0.0
# Episode 246 ended after 23 steps with total reward: 0.0
# Episode 247 ended after 12 steps with total reward: 0.0
# Episode 248 ended after 24 steps with total reward: 0.0
# Episode 249 ended after 5 steps with total reward: 0.0
# Episode 250 ended after 18 steps with total reward: 0.0
# Episode 251 ended after 9 steps with total reward: 0.0
# Episode 252 ended after 7 steps with total reward: 0.0
# Episode 253 ended after 7 steps with total reward: 1.0
# Episode 254 ended after 16 steps with total reward: 0.0
# Episode 255 ended after 8 steps with total reward: 0.0
# Episode 256 ended after 26 steps with total reward: 0.0
# Episode 257 ended after 12 steps with total reward: 0.0
# Episode 258 ended after 8 steps with total reward: 0.0
# Episode 259 ended after 28 steps with total reward: 0.0
# Episode 260 ended after 17 steps with total reward: 0.0
# Episode 261 ended after 6 steps with total reward: 0.0
# Episode 262 ended after 13 steps with total reward: 1.0
# Episode 263 ended after 10 steps with total reward: 0.0
# Episode 264 ended after 10 steps with total reward: 0.0
# Episode 265 ended after 9 steps with total reward: 0.0
# Episode 266 ended after 7 steps with total reward: 0.0
# Episode 267 ended after 13 steps with total reward: 0.0
# Episode 268 ended after 15 steps with total reward: 1.0
# Episode 269 ended after 28 steps with total reward: 0.0
# Episode 270 ended after 17 steps with total reward: 0.0
# Episode 271 ended after 74 steps with total reward: 0.0
# Episode 272 ended after 11 steps with total reward: 0.0
# Episode 273 ended after 20 steps with total reward: 0.0
# Episode 274 ended after 9 steps with total reward: 0.0
# Episode 338 ended after 5 steps with total reward: 0.0
# Episode 339 ended after 9 steps with total reward: 0.0
# Episode 340 ended after 7 steps with total reward: 0.0
# Episode 341 ended after 18 steps with total reward: 0.0
# Episode 342 ended after 29 steps with total reward: 0.0
# Episode 343 ended after 18 steps with total reward: 0.0
# Episode 344 ended after 35 steps with total reward: 0.0
# Episode 345 ended after 55 steps with total reward: 0.0
# Episode 346 ended after 31 steps with total reward: 0.0
# Episode 347 ended after 12 steps with total reward: 0.0
# Episode 348 ended after 14 steps with total reward: 0.0
# Episode 349 ended after 35 steps with total reward: 0.0
# Episode 350 ended after 61 steps with total reward: 0.0
# Episode 351 ended after 16 steps with total reward: 0.0
# Episode 352 ended after 6 steps with total reward: 0.0
# Episode 353 ended after 8 steps with total reward: 0.0
# Episode 354 ended after 13 steps with total reward: 0.0
# Episode 355 ended after 14 steps with total reward: 0.0
# Episode 356 ended after 16 steps with total reward: 0.0
# Episode 357 ended after 7 steps with total reward: 0.0
# Episode 358 ended after 7 steps with total reward: 0.0
# Episode 359 ended after 40 steps with total reward: 0.0
# Episode 360 ended after 4 steps with total reward: 0.0
# Episode 361 ended after 7 steps with total reward: 0.0
# Episode 362 ended after 6 steps with total reward: 0.0
# Episode 363 ended after 9 steps with total reward: 0.0
# Episode 364 ended after 6 steps with total reward: 0.0
# Episode 365 ended after 10 steps with total reward: 0.0
# Episode 366 ended after 22 steps with total reward: 0.0
# Episode 367 ended after 12 steps with total reward: 0.0
# Episode 368 ended after 7 steps with total reward: 0.0
# Episode 369 ended after 15 steps with total reward: 0.0
# Episode 370 ended after 10 steps with total reward: 0.0
# Episode 371 ended after 6 steps with total reward: 0.0
# Episode 372 ended after 10 steps with total reward: 0.0
# Episode 373 ended after 13 steps with total reward: 0.0
# Episode 374 ended after 32 steps with total reward: 1.0
# Episode 375 ended after 17 steps with total reward: 0.0
# Episode 376 ended after 20 steps with total reward: 1.0
# Episode 377 ended after 7 steps with total reward: 0.0
# Episode 378 ended after 37 steps with total reward: 0.0
# Episode 379 ended after 26 steps with total reward: 0.0
# Episode 380 ended after 6 steps with total reward: 0.0
# Episode 381 ended after 19 steps with total reward: 0.0
# Episode 382 ended after 41 steps with total reward: 0.0
# Episode 383 ended after 22 steps with total reward: 1.0
# Episode 384 ended after 34 steps with total reward: 0.0
# Episode 385 ended after 47 steps with total reward: 0.0
# Episode 386 ended after 22 steps with total reward: 0.0
# Episode 387 ended after 36 steps with total reward: 0.0
# Episode 388 ended after 22 steps with total reward: 0.0
# Episode 389 ended after 10 steps with total reward: 0.0
# Episode 390 ended after 15 steps with total reward: 0.0
# Episode 391 ended after 13 steps with total reward: 0.0
# Episode 392 ended after 7 steps with total reward: 0.0
# Episode 393 ended after 11 steps with total reward: 0.0
# Episode 394 ended after 5 steps with total reward: 0.0
# Episode 395 ended after 18 steps with total reward: 0.0
# Episode 396 ended after 12 steps with total reward: 0.0
# Episode 397 ended after 13 steps with total reward: 1.0
# Episode 398 ended after 24 steps with total reward: 0.0
# Episode 399 ended after 6 steps with total reward: 0.0
# Episode 463 ended after 20 steps with total reward: 0.0
# Episode 464 ended after 17 steps with total reward: 0.0
# Episode 465 ended after 7 steps with total reward: 0.0
# Episode 466 ended after 12 steps with total reward: 0.0
# Episode 467 ended after 9 steps with total reward: 0.0
# Episode 468 ended after 17 steps with total reward: 0.0
# Episode 469 ended after 9 steps with total reward: 0.0
# Episode 470 ended after 21 steps with total reward: 1.0
# Episode 471 ended after 34 steps with total reward: 0.0
# Episode 472 ended after 15 steps with total reward: 0.0
# Episode 473 ended after 34 steps with total reward: 0.0
# Episode 474 ended after 20 steps with total reward: 0.0
# Episode 475 ended after 22 steps with total reward: 1.0
# Episode 476 ended after 3 steps with total reward: 0.0
# Episode 477 ended after 7 steps with total reward: 0.0
# Episode 478 ended after 3 steps with total reward: 0.0
# Episode 479 ended after 52 steps with total reward: 0.0
# Episode 480 ended after 5 steps with total reward: 0.0
# Episode 481 ended after 24 steps with total reward: 0.0
# Episode 482 ended after 15 steps with total reward: 0.0
# Episode 483 ended after 9 steps with total reward: 1.0
# Episode 484 ended after 5 steps with total reward: 0.0
# Episode 485 ended after 11 steps with total reward: 0.0
# Episode 486 ended after 17 steps with total reward: 0.0
# Episode 487 ended after 6 steps with total reward: 0.0
# Episode 488 ended after 10 steps with total reward: 0.0
# Episode 489 ended after 3 steps with total reward: 0.0
# Episode 490 ended after 16 steps with total reward: 0.0
# Episode 491 ended after 36 steps with total reward: 0.0
# Episode 492 ended after 13 steps with total reward: 0.0
# Episode 493 ended after 13 steps with total reward: 0.0
# Episode 494 ended after 6 steps with total reward: 0.0
# Episode 495 ended after 5 steps with total reward: 0.0
# Episode 496 ended after 12 steps with total reward: 0.0
# Episode 497 ended after 17 steps with total reward: 0.0
# Episode 498 ended after 22 steps with total reward: 0.0
# Episode 499 ended after 6 steps with total reward: 0.0
# Episode 500 ended after 16 steps with total reward: 0.0
# Episode 501 ended after 7 steps with total reward: 0.0
# Episode 502 ended after 10 steps with total reward: 0.0
# Episode 503 ended after 13 steps with total reward: 0.0
# Episode 504 ended after 7 steps with total reward: 0.0
# Episode 505 ended after 6 steps with total reward: 0.0
# Episode 506 ended after 28 steps with total reward: 0.0
# Episode 507 ended after 9 steps with total reward: 0.0
# Episode 508 ended after 48 steps with total reward: 0.0
# Episode 509 ended after 31 steps with total reward: 1.0
# Episode 510 ended after 6 steps with total reward: 0.0
# Episode 511 ended after 10 steps with total reward: 0.0
# Episode 512 ended after 15 steps with total reward: 1.0
# Episode 513 ended after 23 steps with total reward: 0.0
# Episode 514 ended after 20 steps with total reward: 0.0
# Episode 515 ended after 31 steps with total reward: 0.0
# Episode 516 ended after 9 steps with total reward: 0.0
# Episode 517 ended after 47 steps with total reward: 0.0
# Episode 518 ended after 26 steps with total reward: 0.0
# Episode 519 ended after 18 steps with total reward: 0.0
# Episode 520 ended after 16 steps with total reward: 0.0
# Episode 521 ended after 11 steps with total reward: 0.0
# Episode 522 ended after 10 steps with total reward: 0.0
# Episode 523 ended after 8 steps with total reward: 0.0
# Episode 524 ended after 14 steps with total reward: 0.0
# Episode 525 ended after 6 steps with total reward: 0.0
# Episode 714 ended after 10 steps with total reward: 0.0
# Episode 715 ended after 39 steps with total reward: 0.0
# Episode 716 ended after 18 steps with total reward: 0.0
# Episode 717 ended after 7 steps with total reward: 0.0
# Episode 718 ended after 17 steps with total reward: 0.0
# Episode 719 ended after 24 steps with total reward: 0.0
# Episode 720 ended after 7 steps with total reward: 0.0
# Episode 721 ended after 3 steps with total reward: 0.0
# Episode 722 ended after 31 steps with total reward: 0.0
# Episode 723 ended after 20 steps with total reward: 0.0
# Episode 724 ended after 21 steps with total reward: 0.0
# Episode 725 ended after 13 steps with total reward: 0.0
# Episode 726 ended after 5 steps with total reward: 0.0
# Episode 727 ended after 7 steps with total reward: 0.0
# Episode 728 ended after 13 steps with total reward: 0.0
# Episode 729 ended after 18 steps with total reward: 1.0
# Episode 730 ended after 9 steps with total reward: 0.0
# Episode 731 ended after 18 steps with total reward: 0.0
# Episode 732 ended after 9 steps with total reward: 0.0
# Episode 733 ended after 15 steps with total reward: 0.0
# Episode 734 ended after 50 steps with total reward: 0.0
# Episode 735 ended after 14 steps with total reward: 1.0
# Episode 736 ended after 34 steps with total reward: 0.0
# Episode 737 ended after 8 steps with total reward: 0.0
# Episode 738 ended after 12 steps with total reward: 0.0
# Episode 739 ended after 24 steps with total reward: 0.0
# Episode 740 ended after 18 steps with total reward: 1.0
# Episode 741 ended after 7 steps with total reward: 0.0
# Episode 742 ended after 67 steps with total reward: 1.0
# Episode 743 ended after 40 steps with total reward: 0.0
# Episode 744 ended after 15 steps with total reward: 0.0
# Episode 745 ended after 13 steps with total reward: 0.0
# Episode 746 ended after 23 steps with total reward: 0.0
# Episode 747 ended after 7 steps with total reward: 0.0
# Episode 748 ended after 21 steps with total reward: 0.0
# Episode 749 ended after 5 steps with total reward: 0.0
# Episode 750 ended after 7 steps with total reward: 0.0
# Episode 751 ended after 31 steps with total reward: 1.0
# Episode 752 ended after 11 steps with total reward: 0.0
# Episode 753 ended after 8 steps with total reward: 0.0
# Episode 754 ended after 23 steps with total reward: 0.0
# Episode 755 ended after 14 steps with total reward: 0.0
# Episode 756 ended after 14 steps with total reward: 0.0
# Episode 757 ended after 4 steps with total reward: 0.0
# Episode 758 ended after 19 steps with total reward: 0.0
# Episode 759 ended after 12 steps with total reward: 0.0
# Episode 760 ended after 8 steps with total reward: 0.0
# Episode 761 ended after 32 steps with total reward: 0.0
# Episode 762 ended after 10 steps with total reward: 0.0
# Episode 763 ended after 6 steps with total reward: 0.0
# Episode 764 ended after 24 steps with total reward: 1.0
# Episode 765 ended after 3 steps with total reward: 0.0
# Episode 766 ended after 6 steps with total reward: 0.0
# Episode 767 ended after 6 steps with total reward: 0.0
# Episode 768 ended after 20 steps with total reward: 0.0
# Episode 769 ended after 11 steps with total reward: 0.0
# Episode 770 ended after 60 steps with total reward: 1.0
# Episode 771 ended after 46 steps with total reward: 0.0
# Episode 772 ended after 3 steps with total reward: 0.0
# Episode 773 ended after 5 steps with total reward: 0.0
# Episode 774 ended after 23 steps with total reward: 0.0
# Episode 775 ended after 39 steps with total reward: 0.0
# Episode 776 ended after 18 steps with total reward: 0.0
# Episode 777 ended after 21 steps with total reward: 0.0
# Episode 778 ended after 27 steps with total reward: 0.0
# Episode 779 ended after 23 steps with total reward: 0.0
# Episode 780 ended after 26 steps with total reward: 0.0
# Episode 781 ended after 5 steps with total reward: 0.0
# Episode 782 ended after 26 steps with total reward: 0.0
# Episode 783 ended after 14 steps with total reward: 0.0
# Episode 784 ended after 25 steps with total reward: 0.0
# Episode 785 ended after 10 steps with total reward: 0.0
# Episode 786 ended after 8 steps with total reward: 0.0
# Episode 787 ended after 34 steps with total reward: 1.0
# Episode 788 ended after 7 steps with total reward: 1.0
# Episode 789 ended after 17 steps with total reward: 0.0
# Episode 790 ended after 39 steps with total reward: 0.0
# Episode 791 ended after 16 steps with total reward: 0.0
# Episode 792 ended after 12 steps with total reward: 0.0
# Episode 793 ended after 7 steps with total reward: 0.0
# Episode 794 ended after 9 steps with total reward: 0.0
# Episode 795 ended after 3 steps with total reward: 0.0
# Episode 796 ended after 21 steps with total reward: 0.0
# Episode 797 ended after 37 steps with total reward: 0.0
# Episode 798 ended after 11 steps with total reward: 0.0
# Episode 799 ended after 27 steps with total reward: 0.0
# Episode 800 ended after 29 steps with total reward: 0.0
# Episode 801 ended after 9 steps with total reward: 0.0
# Episode 802 ended after 14 steps with total reward: 0.0
# Episode 803 ended after 10 steps with total reward: 0.0
# Episode 804 ended after 10 steps with total reward: 0.0
# Episode 805 ended after 17 steps with total reward: 0.0
# Episode 806 ended after 11 steps with total reward: 0.0
# Episode 807 ended after 15 steps with total reward: 0.0
# Episode 808 ended after 8 steps with total reward: 0.0
# Episode 809 ended after 13 steps with total reward: 0.0
# Episode 810 ended after 11 steps with total reward: 1.0
# Episode 811 ended after 29 steps with total reward: 0.0
# Episode 812 ended after 47 steps with total reward: 0.0
# Episode 813 ended after 10 steps with total reward: 0.0
# Episode 814 ended after 33 steps with total reward: 0.0
# Episode 815 ended after 24 steps with total reward: 0.0
# Episode 816 ended after 26 steps with total reward: 0.0
# Episode 817 ended after 4 steps with total reward: 0.0
# Episode 818 ended after 15 steps with total reward: 0.0
# Episode 819 ended after 6 steps with total reward: 0.0
# Episode 820 ended after 18 steps with total reward: 0.0
# Episode 821 ended after 21 steps with total reward: 0.0
# Episode 822 ended after 10 steps with total reward: 0.0
# Episode 823 ended after 5 steps with total reward: 0.0
# Episode 824 ended after 13 steps with total reward: 0.0
# Episode 825 ended after 26 steps with total reward: 1.0
# Episode 826 ended after 19 steps with total reward: 0.0
# Episode 827 ended after 11 steps with total reward: 0.0
# Episode 828 ended after 10 steps with total reward: 0.0
# Episode 829 ended after 23 steps with total reward: 0.0
# Episode 830 ended after 12 steps with total reward: 0.0
# Episode 831 ended after 26 steps with total reward: 0.0
# Episode 832 ended after 12 steps with total reward: 0.0
# Episode 833 ended after 12 steps with total reward: 0.0
# Episode 834 ended after 23 steps with total reward: 0.0
# Episode 835 ended after 7 steps with total reward: 0.0
# Episode 836 ended after 15 steps with total reward: 0.0
# Episode 837 ended after 12 steps with total reward: 0.0
# Episode 838 ended after 24 steps with total reward: 0.0
