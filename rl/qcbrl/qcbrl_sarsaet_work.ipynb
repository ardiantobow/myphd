# %%
import numpy as np
import json
import gym
import matplotlib.pyplot as plt
import psutil
import pynvml
from collections import Counter

class ProblemSolver:
    def __init__(self, actions, epsilon=0.1, gamma=0.99, alpha=0.1, lambd=0.9):
        self.actions = actions
        self.epsilon = epsilon
        self.gamma = gamma
        self.alpha = alpha
        self.lambd = lambd
        self.Q = {}  # Q-values table
        self.e = {}  # Eligibility traces table

    def choose_action(self, state):
        if np.isscalar(state):  # Check if state is a scalar (integer or float)
            state_array = np.array([state])  # Convert scalar to numpy array
        else:
            state_array = np.asarray(state)  # Ensure state is a numpy array

        state_tuple = (state_array.item(),) if state_array.ndim == 0 else tuple(state_array.tolist())

        if np.random.rand() < self.epsilon:
            return np.random.choice(self.actions)
        else:
            if state_tuple in self.Q:  # Use the tuple as the key
                return np.argmax(self.Q[state_tuple])
            else:
                return np.random.choice(self.actions)

    def update_Q(self, state, action, reward, next_state, next_action):
        if np.isscalar(state):  # Check if state is a scalar (integer or float)
            state_array = np.array([state])  # Convert scalar to numpy array
        else:
            state_array = np.asarray(state)  # Ensure state is a numpy array

        state_tuple = (state_array.item(),) if state_array.ndim == 0 else tuple(state_array.tolist())

        if state_tuple not in self.Q:
            self.Q[state_tuple] = np.zeros(self.actions)
            self.e[state_tuple] = np.zeros(self.actions)

        if np.isscalar(next_state):  # Check if next_state is a scalar
            next_state_array = np.array([next_state])  # Convert scalar to numpy array with one element
        else:
            next_state_array = np.asarray(next_state)  # Ensure next_state is a numpy array

        if next_state_array.ndim == 0:
            next_state_tuple = (next_state_array.item(),)
        else:
            next_state_tuple = tuple(next_state_array.tolist())

        next_q_values = self.Q.get(next_state_tuple, np.zeros(self.actions))
        delta = reward + self.gamma * next_q_values[next_action] - self.Q[state_tuple][action]
        self.e[state_tuple][action] += 1

        for s in self.Q:
            for a in range(self.actions):
                self.Q[s][a] += self.alpha * delta * self.e[s][a]
                self.e[s][a] *= self.gamma * self.lambd





class Case:
    added_states = set()  # Class attribute to store states already added to the case base

    def __init__(self, problem, solution, trust_value=1):
        self.problem = np.array(problem)  # Convert problem to numpy array
        self.solution = solution
        self.trust_value = trust_value

    @staticmethod
    def retrieve(state, case_base, threshold=0.5):
        similarities = {}
        for case in case_base:
            similarities[case] = Case.sim_q(state, case.problem)  # Compare state with the problem part of the case
        
        sorted_similarities = sorted(similarities.items(), key=lambda x: x[1], reverse=True)
        
        if sorted_similarities:
            most_similar_case = sorted_similarities[0][0] if sorted_similarities[0][1] >= threshold else None
        else:
            most_similar_case = None
        
        return most_similar_case

    @staticmethod
    def reuse(c, case_base, temporary_case_base):
        # Store the new case from the problem solver
        if c not in temporary_case_base:
            temporary_case_base.append(c)
        
        # Check if there are similar cases in case_base
        similar_cases = [case for case in case_base if np.array_equal(case.problem, c.problem)]
        for similar_case in similar_cases:
            if similar_case not in temporary_case_base:
                temporary_case_base.append(similar_case)

    @staticmethod
    def revise(case_base, temporary_case_base, episode_ended_successfully):
        for case in temporary_case_base:
            if episode_ended_successfully and case in case_base:
                case.trust_value += 0.1  # Increment trust value if the episode ended successfully and the case is in the case base
            elif not episode_ended_successfully and case in case_base:
                case.trust_value -= 0.1  # Decrement trust value if the episode ended unsuccessfully and the case is in the case base
            case.trust_value = max(0, min(case.trust_value,1))  # Ensure trust value is within[0,1]

    @staticmethod
    def retain(case_base, temporary_case_base, episode_ended_successfully, threshold):
        if episode_ended_successfully:
            # Iterate through the temporary case base to find the last occurrence of each unique state
            for case in reversed(temporary_case_base):
                state = tuple(np.atleast_1d(case.problem))
                # Check if the state is already in the case base or has been added previously
                if state not in Case.added_states:
                    # Add the case to the case base if the state is new
                    case_base.append(case)
                    Case.added_states.add(state)
            
            # Filter case_base based on trust_value
            filtered_case_base = []
            for case in case_base:
                # print(f"trust value >= Threshold?: {case.trust_value} >= {threshold}?")
                if case.trust_value >= threshold:
                    # print(f"problem | trust value: {case.problem} | {case.trust_value}")
                    # print("case saved dong")
                    filtered_case_base.append(case)
                else:
                    # print(f"problem | trust value: {case.problem} | {case.trust_value}")
                    # print("case unsaved dong")
                    pass

            return filtered_case_base
        else:
            return case_base  # Return original case_base if episode is not successful

            
    @staticmethod
    def sim_q(state1, state2):
        state1 = np.atleast_1d(state1)  # Ensure state1 is at least 1-dimensional
        state2 = np.atleast_1d(state2)  # Ensure state2 is at least 1-dimensional
        CNDMaxDist = 6  # Maximum distance between two nodes in the CND
        v = state1.size  # Total number of objects the agent can perceive
        DistQ = np.sum([Case.Dmin_phi(Objic, Objip) for Objic, Objip in zip(state1, state2)])
        similarity = (CNDMaxDist * v - DistQ) / (CNDMaxDist * v)
        return similarity

    @staticmethod
    def Dmin_phi(X1, X2):
        return np.max(np.abs(X1 - X2))

class QCBRL:
    def __init__(self, actions, threshold=0.0, epsilon=0.1, gamma=0.99, alpha=0.1, lambd=0.9):
        self.problem_solver = ProblemSolver(actions, epsilon, gamma, alpha, lambd)
        self.case_base = []
        self.threshold = threshold
        self.temporary_case_base = []
        # self.load_case_base()  # Load case base at initialization

    def train(self, episodes, max_steps, render=False):
        env = gym.make('FrozenLake-v1')
        rewards = []
        episode_rewards = []
        memory_usage = []
        gpu_memory_usage = []
        successful_episodes = 0  # Initialize counter for successful episodes

        pynvml.nvmlInit()
        handle = pynvml.nvmlDeviceGetHandleByIndex(0)  # GPU Index

        for episode in range(1, episodes + 1):
            state = env.reset()
            total_reward = 0
            self.temporary_case_base = []

            for step in range(max_steps):
                if render:
                    env.render()
                action, next_state = self.take_action(state)
                next_state, reward, done, _ = env.step(action)
                next_state = np.array(next_state)
                total_reward += reward

                state = next_state

                # Print Q-table
                print("Q-table:")
                for state, q_values in self.problem_solver.Q.items():
                    print(f"State: {state}, Q-values: {q_values}")

                if done:
                    rewards.append(total_reward)
                    episode_rewards.append(total_reward)
                    if reward == 1.0:
                        episode_ended_successfully = True
                        successful_episodes += 1  # Increment successful episode counter
                    else:
                        episode_ended_successfully = False

                    print(f"Episode {episode} ended after {step + 1} steps with total reward: {total_reward}")
                    break

                # Update Q-table
                self.problem_solver.update_Q(state, action, reward, next_state, self.problem_solver.choose_action(next_state))

            Case.revise(self.case_base, self.temporary_case_base, episode_ended_successfully)
            self.case_base = Case.retain(self.case_base, self.temporary_case_base, episode_ended_successfully, self.threshold)

            memory_usage.append(psutil.virtual_memory().percent)
            gpu_memory_usage.append(pynvml.nvmlDeviceGetMemoryInfo(handle).used / 1024**2)

        self.save_case_base_temporary()  # Save temporary case base after training
        self.save_case_base()  # Save case base after training

        env.close()
        self.plot_rewards(episode_rewards)
        self.plot_resources(memory_usage, gpu_memory_usage)

        # Calculate and display percentage of successful episodes
        success_percentage = (successful_episodes / episodes) * 100
        print(f"Percentage of Successful Episodes: {success_percentage}%")



    def take_action(self, state):
        if np.isscalar(state):
            state_array = np.array([state])
        else:
            state_array = np.asarray(state)

        similar_solution = Case.retrieve(state_array, self.case_base)
        if similar_solution is not None:
            action = similar_solution.solution
            next_state = state
        else:
            action = self.problem_solver.choose_action(state_array)
            next_state = state_array

        if not isinstance(next_state, np.ndarray):
            next_state = np.array(next_state)

        action = self.problem_solver.choose_action(state_array.flatten())
        next_state = next_state.flatten()

        c = Case(state, action)
        Case.reuse(c, self.case_base, self.temporary_case_base)

        return action, next_state


    def save_case_base_temporary(self):
        filename = "case_base_temporary.json"
        case_base_data = [{"problem": case.problem.tolist() if isinstance(case.problem, np.ndarray) else int(case.problem), 
                        "solution": int(case.solution), 
                        "trust_value": int(case.trust_value)} for case in self.temporary_case_base]
        with open(filename, 'w') as file:
            json.dump(case_base_data, file)
        print("Temporary case base saved successfully.")




    def save_case_base(self):
        filename = "case_base.json"
        case_base_data = [{"problem": case.problem.tolist(), "solution": case.solution, "trust_value": case.trust_value} for case in self.case_base]
        with open(filename, 'w') as file:
            json.dump(case_base_data, file)

            print("Case base saved successfully.")  # Add this line to check if the case base is being saved
        
    def load_case_base(self):
        filename = "case_base.json"
        try:
            with open(filename, 'r') as file:
                case_base_data = json.load(file)
                self.case_base = [Case(np.array(case["problem"]), case["solution"], case["trust_value"]) for case in case_base_data]
                print("Case base loaded successfully.")  # Add this line to check if the case base is being loaded
        except FileNotFoundError:
            print("Case base file not found. Starting with an empty case base.")

    def plot_rewards(self, rewards):
        plt.plot(rewards)
        plt.xlabel('Episode')
        plt.ylabel('Total Reward')
        plt.title('Rewards over Episodes')
        plt.grid(True)
        plt.show() 

    def plot_resources(self, memory_usage, gpu_memory_usage):
        plt.plot(memory_usage, label='Memory (%)')
        plt.plot(gpu_memory_usage, label='GPU Memory (MB)')
        plt.xlabel('Episode')
        plt.ylabel('Resource Usage')
        plt.title('Resource Usage over Episodes')
        plt.legend()
        plt.grid(True)
        plt.show()

if __name__ == "__main__":
    actions = 4  # Number of actions in FrozenLake-v1
    agent = QCBRL(actions)
    agent.train(episodes=1000, max_steps=100000)
# Out:
# /home/ardie85/PHD/Research/code/.venv/lib/python3.10/site-packages/gym/wrappers/monitoring/video_recorder.py:9: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   import distutils.spawn
# Q-table:
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 1 ended after 5 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 2 ended after 63 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 3 ended after 31 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 4 ended after 43 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 5 ended after 6 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 6 ended after 17 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 7 ended after 30 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 8 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 9 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 10 ended after 2 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 11 ended after 9 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 12 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 13 ended after 12 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 14 ended after 5 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 15 ended after 25 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 16 ended after 15 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 17 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 18 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 19 ended after 6 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 20 ended after 8 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 21 ended after 5 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 22 ended after 8 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 23 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 24 ended after 9 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 25 ended after 10 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 26 ended after 12 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 27 ended after 12 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 28 ended after 20 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 29 ended after 19 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 30 ended after 16 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 31 ended after 17 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 32 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 33 ended after 4 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 34 ended after 8 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 35 ended after 7 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 36 ended after 8 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 37 ended after 9 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 38 ended after 16 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 39 ended after 6 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 40 ended after 7 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 41 ended after 9 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 42 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 43 ended after 12 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 44 ended after 4 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 45 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 46 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 47 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 48 ended after 50 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 49 ended after 24 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 50 ended after 23 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 51 ended after 17 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 52 ended after 7 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 53 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 54 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 55 ended after 3 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 56 ended after 2 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 57 ended after 18 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 58 ended after 15 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 59 ended after 7 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 60 ended after 5 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 61 ended after 17 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 62 ended after 25 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 63 ended after 9 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 64 ended after 17 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 65 ended after 25 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 66 ended after 10 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 67 ended after 10 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 68 ended after 8 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 69 ended after 5 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 70 ended after 2 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 71 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 72 ended after 4 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 73 ended after 12 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 74 ended after 6 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 75 ended after 24 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 76 ended after 8 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# ...
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 977 ended after 15 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 978 ended after 10 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 979 ended after 2 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 980 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 981 ended after 13 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 982 ended after 16 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 983 ended after 18 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 984 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 985 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 986 ended after 2 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 987 ended after 20 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 988 ended after 5 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 989 ended after 23 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 990 ended after 6 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 991 ended after 14 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 992 ended after 13 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 993 ended after 22 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 994 ended after 22 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 995 ended after 5 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 996 ended after 2 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 997 ended after 41 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 998 ended after 7 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 999 ended after 11 steps with total reward: 0.0
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Q-table:
# State: (4,), Q-values: [0. 0. 0. 0.]
# Episode 1000 ended after 20 steps with total reward: 0.0
# Temporary case base saved successfully.
# Case base saved successfully.
# Percentage of Successful Episodes: 0.0%
